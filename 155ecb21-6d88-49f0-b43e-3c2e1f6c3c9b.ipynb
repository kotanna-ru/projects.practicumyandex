# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Ознакомление-с--данными" data-toc-modified-id="Ознакомление-с--данными-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Ознакомление с  данными</a></span></li><li><span><a href="#Проверка-расчета-эффективности-обогащения" data-toc-modified-id="Проверка-расчета-эффективности-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Проверка расчета эффективности обогащения</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-элементов-на-каждом-этапе" data-toc-modified-id="Изменение-концентрации-элементов-на-каждом-этапе-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрации элементов на каждом этапе</a></span></li><li><span><a href="#Распределения-размеров-гранул-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Распределения-размеров-гранул-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Распределения размеров гранул на обучающей и тестовой выборках</a></span></li><li><span><a href="#Исследуем-суммарные-концентрации" data-toc-modified-id="Исследуем-суммарные-концентрации-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследуем суммарные концентрации</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Напишим-функции-для-вычисления-итоговой-sMAPE." data-toc-modified-id="Напишим-функции-для-вычисления-итоговой-sMAPE.-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Напишим функции для вычисления итоговой sMAPE.</a></span></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Cлучайный-лес" data-toc-modified-id="Cлучайный-лес-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Cлучайный лес</a></span></li></ul></li><li><span><a href="#Проверка-лучшей-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-лучшей-модели-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка лучшей модели на тестовой выборке</a></span></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Ознакомление с  данными

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import  make_scorer, mean_absolute_error
from sklearn.dummy import DummyRegressor
import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# %%
try:
    df_train = pd.read_csv('D:\\Мои документы\\DS\\gold_industry_train.csv')
    df_test = pd.read_csv('D:\\Мои документы\\DS\\gold_industry_test.csv')
    df = pd.read_csv('D:\\Мои документы\\DS\\gold_industry_full.csv')
except:
    df_train = pd.read_csv('/datasets/gold_industry_train.csv')
    df_test = pd.read_csv('/datasets/gold_industry_test.csv')
    df = pd.read_csv('/datasets/gold_industry_full.csv')

# %%
pd.options.display.max_columns = None
display(df_train.head(),df_test.head(), df.head())
# Out:
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                55.486599                          11.986616
# 1                57.278666                          11.971193
# 2                57.510649                          11.920603
# 3                57.792734                          11.630094
# 4                56.047189                          10.957755
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# 0                            6.007990                       999.706909
# 1                            6.005766                      1000.286398
# 2                            6.197377                       999.719565
# 3                            6.203177                       999.814770
# 4                            6.198826                       999.678690
#
#    rougher.state.floatbank10_a_level  rougher.state.floatbank10_b_air  \
# 0                        -404.066986                      1603.011353
# 1                        -400.065196                      1600.754587
# 2                        -400.074028                      1599.337330
# 3                        -400.200179                      1600.059442
# 4                        -399.752729                      1600.208824
#
#    rougher.state.floatbank10_b_level  rougher.state.floatbank10_c_air  \
# 0                        -434.715027                      1602.375000
# 1                        -449.953435                      1600.479580
# 2                        -450.008530                      1599.672797
# 3                        -450.619948                      1600.012842
# 4                        -449.599614                      1600.357732
#
#    rougher.state.floatbank10_c_level  rougher.state.floatbank10_d_air  \
# 0                        -442.204468                      1598.937256
# 1                        -449.830646                      1600.527589
# 2                        -449.954491                      1599.849325
# 3                        -449.910497                      1597.725177
# 4                        -450.034364                      1599.759049
#
#    rougher.state.floatbank10_d_level  rougher.state.floatbank10_e_air  \
# 0                        -451.294128                      1404.472046
# 1                        -449.953649                      1399.227084
# 2                        -449.954185                      1399.180945
# 3                        -450.130127                      1400.943157
# 4                        -449.909799                      1401.560902
#
#    rougher.state.floatbank10_e_level  rougher.state.floatbank10_f_air  \
# 0                        -455.462982                      1416.354980
# 1                        -450.869848                      1399.719514
# 2                        -449.937588                      1400.316682
# 3                        -450.030142                      1400.234743
# 4                        -448.877187                      1401.160227
#
#    rougher.state.floatbank10_f_level  rougher.input.floatbank11_sulfate  \
# 0                        -451.939636                          11.836743
# 1                        -450.119001                          11.996163
# 2                        -450.527147                          11.920305
# 3                        -449.790835                          11.692450
# 4                        -450.407128                          10.960521
#
#    rougher.input.floatbank11_xanthate  \
# 0                            6.005818
# 1                            6.012594
# 2                            6.204633
# 3                            6.196578
# 4                            6.194897
#
#    rougher.calculation.sulfate_to_au_concentrate  \
# 0                                   41885.707031
# 1                                   42050.861809
# 2                                   42018.101184
# 3                                   42029.447991
# 4                                   42125.354245
#
#    rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                        3481.779053
# 1                                        3498.370979
# 2                                        3495.348910
# 3                                        3498.578313
# 4                                        3494.800771
#
#    rougher.calculation.floatbank11_sulfate_to_au_feed  \
# 0                                        3520.337158
# 1                                        3489.981857
# 2                                        3502.359819
# 3                                        3499.162912
# 4                                        3506.679315
#
#    rougher.calculation.au_pb_ratio  rougher.output.concentrate_au  \
# 0                         2.838687                      19.793808
# 1                         2.858998                      20.050975
# 2                         2.945989                      19.737170
# 3                         3.002340                      19.320810
# 4                         3.169615                      19.216101
#
#    rougher.output.concentrate_ag  rougher.output.concentrate_pb  \
# 0                      11.500771                       7.101074
# 1                      11.615865                       7.278807
# 2                      11.695753                       7.216833
# 3                      11.915047                       7.175616
# 4                      12.411054                       7.240205
#
#    rougher.output.concentrate_sol  rougher.output.recovery  \
# 0                       28.029297                87.107763
# 1                       28.067063                86.843261
# 2                       27.454037                86.842308
# 3                       27.341277                87.226430
# 4                       27.041023                86.688794
#
#    rougher.output.tail_au  rougher.output.tail_ag  rougher.output.tail_pb  \
# 0                1.170244                5.008018                0.508728
# 1                1.184827                4.955378                0.536689
# 2                1.162562                4.843460                0.546416
# 3                1.079755                4.655288                0.542525
# 4                1.012642                4.552800                0.515438
#
#    rougher.output.tail_sol  primary_cleaner.input.sulfate  \
# 0                19.154297                     127.092003
# 1                18.965234                     125.629232
# 2                18.808533                     123.819808
# 3                19.330200                     122.270188
# 4                19.267422                     117.988169
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         10.128295                             7.25
# 1                         10.296251                             7.25
# 2                         11.316280                             7.25
# 3                         11.322140                             7.25
# 4                         11.913613                             7.25
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        0.988759                             1549.775757
# 1                        1.002663                             1576.166671
# 2                        0.991265                             1601.556163
# 3                        0.996739                             1599.968720
# 4                        1.009869                             1601.339707
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -498.912140
# 1                               -500.904965
# 2                               -499.997791
# 3                               -500.951778
# 4                               -498.975456
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1551.434204
# 1                             1575.950626
# 2                             1600.386685
# 3                             1600.659236
# 4                             1601.437854
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -516.403442
# 1                               -499.865889
# 2                               -500.607762
# 3                               -499.677094
# 4                               -500.323246
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1549.873901
# 1                             1575.994189
# 2                             1602.003542
# 3                             1600.304144
# 4                             1599.581894
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -498.666595
# 1                               -499.315107
# 2                               -500.870069
# 3                               -500.727997
# 4                               -500.888152
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1554.367432
# 1                             1574.479259
# 2                             1599.541515
# 3                             1600.449520
# 4                             1602.649541
#
#    primary_cleaner.state.floatbank8_d_level  \
# 0                               -493.428131
# 1                               -498.931665
# 2                               -499.827444
# 3                               -500.052575
# 4                               -500.593010
#
#    primary_cleaner.output.concentrate_au  \
# 0                              34.174427
# 1                              34.118526
# 2                              33.969464
# 3                              28.260743
# 4                              33.044932
#
#    primary_cleaner.output.concentrate_ag  \
# 0                               8.547551
# 1                               8.558743
# 2                               8.603505
# 3                               7.221879
# 4                               9.089428
#
#    primary_cleaner.output.concentrate_pb  \
# 0                              10.389648
# 1                              10.497069
# 2                              10.354494
# 3                               8.496563
# 4                               9.986786
#
#    primary_cleaner.output.concentrate_sol  primary_cleaner.output.tail_au  \
# 0                               19.529297                        2.106679
# 1                               19.369147                        2.353017
# 2                               19.167579                        2.416800
# 3                               15.978538                        2.262051
# 4                               19.199864                        2.277073
#
#    primary_cleaner.output.tail_ag  primary_cleaner.output.tail_pb  \
# 0                       14.936526                        2.534912
# 1                       16.250511                        3.049646
# 2                       16.491823                        3.124664
# 3                       16.024359                        2.960362
# 4                       16.480185                        3.112100
#
#    primary_cleaner.output.tail_sol  secondary_cleaner.state.floatbank2_a_air  \
# 0                         7.476074                                 25.853109
# 1                         6.733907                                 25.880539
# 2                         6.471768                                 26.005245
# 3                         6.843791                                 25.942508
# 4                         6.550154                                 26.024787
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -498.526489
# 1                                 -499.989656
# 2                                 -499.929616
# 3                                 -499.176749
# 4                                 -500.279091
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 23.893660
# 1                                 23.889530
# 2                                 23.886657
# 3                                 23.955516
# 4                                 23.955345
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -501.406281
# 1                                 -500.372428
# 2                                 -499.951928
# 3                                 -499.848796
# 4                                 -500.593614
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 23.961798
# 1                                 23.970550
# 2                                 23.913535
# 3                                 23.966838
# 4                                 23.985703
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -495.262817
# 1                                 -500.085473
# 2                                 -499.442343
# 3                                 -500.008812
# 4                                 -500.083811
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 21.940409
# 1                                 22.085714
# 2                                 23.957717
# 3                                 23.954443
# 4                                 23.958945
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -499.340973
# 1                                 -499.446897
# 2                                 -499.901982
# 3                                 -499.944710
# 4                                 -499.990309
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level  \
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
#    secondary_cleaner.output.tail_au  secondary_cleaner.output.tail_ag  \
# 0                          2.606185                         14.500184
# 1                          2.488248                         14.265474
# 2                          2.458187                         14.115662
# 3                          2.322062                         13.732071
# 4                          2.330448                         14.079996
#
#    secondary_cleaner.output.tail_pb  secondary_cleaner.output.tail_sol  \
# 0                          4.694824                           8.764648
# 1                          4.592547                           9.001494
# 2                          4.624775                           8.842896
# 3                          4.482453                           9.122857
# 4                          4.470737                           8.871028
#
#    final.output.concentrate_au  final.output.concentrate_ag  \
# 0                    42.192020                     6.055403
# 1                    42.701629                     6.029369
# 2                    42.657501                     6.055926
# 3                    42.689819                     6.047977
# 4                    42.774141                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.recovery  final.output.tail_au  final.output.tail_ag  \
# 0              70.541216              2.143149             10.411962
# 1              69.266198              2.224930             10.462676
# 2              68.116445              2.257889             10.507046
# 3              68.347543              2.146849             10.422762
# 4              66.927016              2.055292             10.360302
#
#    final.output.tail_pb  final.output.tail_sol
# 0              0.895447              16.904297
# 1              0.927452              16.634514
# 2              0.953716              16.208849
# 3              0.883763              16.532835
# 4              0.792826              16.525686
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2017-12-09 14:59:59               4.365491               6.158718
# 1  2017-12-09 15:59:59               4.362781               6.048130
# 2  2017-12-09 16:59:59               5.081681               6.082745
# 3  2017-12-09 17:59:59               5.145949               6.084374
# 4  2017-12-09 18:59:59               5.735249               6.165220
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               3.875727               39.135119               555.820208
# 1               3.902537               39.713906               544.731687
# 2               4.564078               37.208683               558.155110
# 3               4.768124               36.808874               539.713765
# 4               4.512346               37.810642               558.713584
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                94.544358                           6.146982
# 1               123.742430                           6.210119
# 2                82.610855                           7.363824
# 3                77.984784                           6.927072
# 4                86.434874                           7.823471
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# 0                            9.308612                      1196.238112
# 1                            9.297709                      1201.904177
# 2                            9.003562                      1200.826926
# 3                            8.955597                      1199.292489
# 4                            7.490356                      1198.005449
#
#    rougher.state.floatbank10_a_level  rougher.state.floatbank10_b_air  \
# 0                        -299.862743                      1147.248241
# 1                        -299.907308                      1154.087804
# 2                        -300.124116                      1150.754676
# 3                        -299.778385                      1152.512559
# 4                        -300.283401                      1099.481500
#
#    rougher.state.floatbank10_b_level  rougher.state.floatbank10_c_air  \
# 0                        -500.363165                      1047.279065
# 1                        -500.036580                      1054.009756
# 2                        -499.986009                      1049.182824
# 3                        -500.338106                      1052.601592
# 4                        -499.702465                       999.539264
#
#    rougher.state.floatbank10_c_level  rougher.state.floatbank10_d_air  \
# 0                        -500.354091                       948.756608
# 1                        -500.237335                       944.138793
# 2                        -500.014696                       948.085464
# 3                        -499.695075                       955.171539
# 4                        -499.306051                       889.445596
#
#    rougher.state.floatbank10_d_level  rougher.state.floatbank10_e_air  \
# 0                        -498.439416                       849.441918
# 1                        -496.866953                       851.589767
# 2                        -499.997003                       850.170086
# 3                        -500.294989                       851.957342
# 4                        -498.118617                       800.533525
#
#    rougher.state.floatbank10_e_level  rougher.state.floatbank10_f_air  \
# 0                        -499.255503                       850.112246
# 1                        -499.040466                       851.345606
# 2                        -500.270334                       849.557905
# 3                        -499.779541                       850.765662
# 4                        -499.765068                       800.510356
#
#    rougher.state.floatbank10_f_level  rougher.input.floatbank11_sulfate  \
# 0                        -499.407112                           6.168939
# 1                        -499.122561                           6.209517
# 2                        -500.198702                           7.358308
# 3                        -501.030559                           6.929364
# 4                        -497.289533                           7.824875
#
#    rougher.input.floatbank11_xanthate  primary_cleaner.input.sulfate  \
# 0                            9.309852                      95.248427
# 1                            9.297194                      98.880538
# 2                            9.000624                     119.497545
# 3                            8.920717                     108.080163
# 4                            7.500678                     117.750648
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                          8.078957                         6.500000
# 1                          7.984164                         6.500000
# 2                          8.003752                         6.500000
# 3                          7.970121                         6.660000
# 4                          6.954311                         6.426667
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        1.283045                             1648.759906
# 1                        1.241969                             1646.547763
# 2                        1.259741                             1647.368779
# 3                        0.774909                             1652.660845
# 4                        0.731271                             1649.411497
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -399.862053
# 1                               -398.977083
# 2                               -399.788506
# 3                               -399.702218
# 4                               -399.853156
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1650.135395
# 1                             1648.212240
# 2                             1648.395206
# 3                             1651.203128
# 4                             1648.917211
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -399.957321
# 1                               -400.383265
# 2                               -400.166490
# 3                               -400.291472
# 4                               -400.321866
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1648.831890
# 1                             1648.917387
# 2                             1648.953828
# 3                             1651.924848
# 4                             1649.117753
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -400.586116
# 1                               -399.521344
# 2                               -400.468641
# 3                               -398.058033
# 4                               -399.645348
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1649.464582
# 1                             1651.498591
# 2                             1649.821569
# 3                             1650.782696
# 4                             1650.398209
#
#    primary_cleaner.state.floatbank8_d_level  \
# 0                               -400.673303
# 1                               -399.745329
# 2                               -400.071884
# 3                               -399.597977
# 4                               -400.654533
#
#    secondary_cleaner.state.floatbank2_a_air  \
# 0                                 34.940919
# 1                                 34.980742
# 2                                 34.952967
# 3                                 35.038256
# 4                                 34.894598
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -500.150510
# 1                                 -498.131002
# 2                                 -501.204647
# 3                                 -500.102649
# 4                                 -498.444587
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 30.031867
# 1                                 29.968453
# 2                                 29.927025
# 3                                 30.066959
# 4                                 30.020745
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -500.328335
# 1                                 -586.013330
# 2                                 -500.106628
# 3                                 -500.211499
# 4                                 -533.831343
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 26.033990
# 1                                 25.971737
# 2                                 25.978253
# 3                                 26.013515
# 4                                 26.022094
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -500.147792
# 1                                 -499.608392
# 2                                 -499.890060
# 3                                 -500.054597
# 4                                 -499.725484
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 22.952306
# 1                                 22.958448
# 2                                 23.004376
# 3                                 22.988928
# 4                                 22.992992
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -500.037678
# 1                                 -499.821308
# 2                                 -500.014529
# 3                                 -499.981410
# 4                                 -499.891405
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 23.018622
# 1                                 23.024963
# 2                                 22.993827
# 3                                 23.032807
# 4                                 23.001911
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -500.492702
# 1                                 -501.153409
# 2                                 -501.559663
# 3                                 -501.287889
# 4                                 -499.947838
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 20.020205
# 1                                 20.054122
# 2                                 20.029144
# 3                                 19.977466
# 4                                 20.023735
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -500.220296
# 1                                 -500.314711
# 2                                 -500.000662
# 3                                 -500.159903
# 4                                 -499.713680
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                 17.963512
# 1                                 17.979515
# 2                                 18.012723
# 3                                 17.980463
# 4                                 17.990955
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -499.939490
# 1                                 -499.272871
# 2                                 -500.024764
# 3                                 -500.504602
# 4                                 -500.334769
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                 12.990306
# 1                                 12.992404
# 2                                 13.016445
# 3                                 12.949071
# 4                                 13.007523
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.080993
# 1                                 -499.976268
# 2                                 -500.058432
# 3                                 -500.009937
# 4                                 -499.968459
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 19.990336
# 1                                 20.013986
# 2                                 19.973767
# 3                                 20.010332
# 4                                 19.995999
#
#    secondary_cleaner.state.floatbank6_a_level
# 0                                 -499.191575
# 1                                 -500.625471
# 2                                 -501.394155
# 3                                 -508.337973
# 4                                 -499.788805
#                   date  rougher.input.feed_au  rougher.input.feed_ag  \
# 0  2016-01-15 00:00:00               6.486150               6.100378
# 1  2016-01-15 01:00:00               6.478583               6.161113
# 2  2016-01-15 02:00:00               6.362222               6.116455
# 3  2016-01-15 03:00:00               6.118189               6.043309
# 4  2016-01-15 04:00:00               5.663707               6.060915
#
#    rougher.input.feed_pb  rougher.input.feed_sol  rougher.input.feed_rate  \
# 0               2.284912               36.808594               523.546326
# 1               2.266033               35.753385               525.290581
# 2               2.159622               35.971630               530.026610
# 3               2.037807               36.862241               542.590390
# 4               1.786875               34.347666               540.531893
#
#    rougher.input.feed_size  rougher.input.floatbank10_sulfate  \
# 0                55.486599                          11.986616
# 1                57.278666                          11.971193
# 2                57.510649                          11.920603
# 3                57.792734                          11.630094
# 4                56.047189                          10.957755
#
#    rougher.input.floatbank10_xanthate  rougher.state.floatbank10_a_air  \
# 0                            6.007990                       999.706909
# 1                            6.005766                      1000.286398
# 2                            6.197377                       999.719565
# 3                            6.203177                       999.814770
# 4                            6.198826                       999.678690
#
#    rougher.state.floatbank10_a_level  rougher.state.floatbank10_b_air  \
# 0                        -404.066986                      1603.011353
# 1                        -400.065196                      1600.754587
# 2                        -400.074028                      1599.337330
# 3                        -400.200179                      1600.059442
# 4                        -399.752729                      1600.208824
#
#    rougher.state.floatbank10_b_level  rougher.state.floatbank10_c_air  \
# 0                        -434.715027                      1602.375000
# 1                        -449.953435                      1600.479580
# 2                        -450.008530                      1599.672797
# 3                        -450.619948                      1600.012842
# 4                        -449.599614                      1600.357732
#
#    rougher.state.floatbank10_c_level  rougher.state.floatbank10_d_air  \
# 0                        -442.204468                      1598.937256
# 1                        -449.830646                      1600.527589
# 2                        -449.954491                      1599.849325
# 3                        -449.910497                      1597.725177
# 4                        -450.034364                      1599.759049
#
#    rougher.state.floatbank10_d_level  rougher.state.floatbank10_e_air  \
# 0                        -451.294128                      1404.472046
# 1                        -449.953649                      1399.227084
# 2                        -449.954185                      1399.180945
# 3                        -450.130127                      1400.943157
# 4                        -449.909799                      1401.560902
#
#    rougher.state.floatbank10_e_level  rougher.state.floatbank10_f_air  \
# 0                        -455.462982                      1416.354980
# 1                        -450.869848                      1399.719514
# 2                        -449.937588                      1400.316682
# 3                        -450.030142                      1400.234743
# 4                        -448.877187                      1401.160227
#
#    rougher.state.floatbank10_f_level  rougher.input.floatbank11_sulfate  \
# 0                        -451.939636                          11.836743
# 1                        -450.119001                          11.996163
# 2                        -450.527147                          11.920305
# 3                        -449.790835                          11.692450
# 4                        -450.407128                          10.960521
#
#    rougher.input.floatbank11_xanthate  \
# 0                            6.005818
# 1                            6.012594
# 2                            6.204633
# 3                            6.196578
# 4                            6.194897
#
#    rougher.calculation.sulfate_to_au_concentrate  \
# 0                                   41885.707031
# 1                                   42050.861809
# 2                                   42018.101184
# 3                                   42029.447991
# 4                                   42125.354245
#
#    rougher.calculation.floatbank10_sulfate_to_au_feed  \
# 0                                        3481.779053
# 1                                        3498.370979
# 2                                        3495.348910
# 3                                        3498.578313
# 4                                        3494.800771
#
#    rougher.calculation.floatbank11_sulfate_to_au_feed  \
# 0                                        3520.337158
# 1                                        3489.981857
# 2                                        3502.359819
# 3                                        3499.162912
# 4                                        3506.679315
#
#    rougher.calculation.au_pb_ratio  rougher.output.concentrate_au  \
# 0                         2.838687                      19.793808
# 1                         2.858998                      20.050975
# 2                         2.945989                      19.737170
# 3                         3.002340                      19.320810
# 4                         3.169615                      19.216101
#
#    rougher.output.concentrate_ag  rougher.output.concentrate_pb  \
# 0                      11.500771                       7.101074
# 1                      11.615865                       7.278807
# 2                      11.695753                       7.216833
# 3                      11.915047                       7.175616
# 4                      12.411054                       7.240205
#
#    rougher.output.concentrate_sol  rougher.output.recovery  \
# 0                       28.029297                87.107763
# 1                       28.067063                86.843261
# 2                       27.454037                86.842308
# 3                       27.341277                87.226430
# 4                       27.041023                86.688794
#
#    rougher.output.tail_au  rougher.output.tail_ag  rougher.output.tail_pb  \
# 0                1.170244                5.008018                0.508728
# 1                1.184827                4.955378                0.536689
# 2                1.162562                4.843460                0.546416
# 3                1.079755                4.655288                0.542525
# 4                1.012642                4.552800                0.515438
#
#    rougher.output.tail_sol  primary_cleaner.input.sulfate  \
# 0                19.154297                     127.092003
# 1                18.965234                     125.629232
# 2                18.808533                     123.819808
# 3                19.330200                     122.270188
# 4                19.267422                     117.988169
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         10.128295                             7.25
# 1                         10.296251                             7.25
# 2                         11.316280                             7.25
# 3                         11.322140                             7.25
# 4                         11.913613                             7.25
#
#    primary_cleaner.input.xanthate  primary_cleaner.state.floatbank8_a_air  \
# 0                        0.988759                             1549.775757
# 1                        1.002663                             1576.166671
# 2                        0.991265                             1601.556163
# 3                        0.996739                             1599.968720
# 4                        1.009869                             1601.339707
#
#    primary_cleaner.state.floatbank8_a_level  \
# 0                               -498.912140
# 1                               -500.904965
# 2                               -499.997791
# 3                               -500.951778
# 4                               -498.975456
#
#    primary_cleaner.state.floatbank8_b_air  \
# 0                             1551.434204
# 1                             1575.950626
# 2                             1600.386685
# 3                             1600.659236
# 4                             1601.437854
#
#    primary_cleaner.state.floatbank8_b_level  \
# 0                               -516.403442
# 1                               -499.865889
# 2                               -500.607762
# 3                               -499.677094
# 4                               -500.323246
#
#    primary_cleaner.state.floatbank8_c_air  \
# 0                             1549.873901
# 1                             1575.994189
# 2                             1602.003542
# 3                             1600.304144
# 4                             1599.581894
#
#    primary_cleaner.state.floatbank8_c_level  \
# 0                               -498.666595
# 1                               -499.315107
# 2                               -500.870069
# 3                               -500.727997
# 4                               -500.888152
#
#    primary_cleaner.state.floatbank8_d_air  \
# 0                             1554.367432
# 1                             1574.479259
# 2                             1599.541515
# 3                             1600.449520
# 4                             1602.649541
#
#    primary_cleaner.state.floatbank8_d_level  \
# 0                               -493.428131
# 1                               -498.931665
# 2                               -499.827444
# 3                               -500.052575
# 4                               -500.593010
#
#    primary_cleaner.output.concentrate_au  \
# 0                              34.174427
# 1                              34.118526
# 2                              33.969464
# 3                              28.260743
# 4                              33.044932
#
#    primary_cleaner.output.concentrate_ag  \
# 0                               8.547551
# 1                               8.558743
# 2                               8.603505
# 3                               7.221879
# 4                               9.089428
#
#    primary_cleaner.output.concentrate_pb  \
# 0                              10.389648
# 1                              10.497069
# 2                              10.354494
# 3                               8.496563
# 4                               9.986786
#
#    primary_cleaner.output.concentrate_sol  primary_cleaner.output.tail_au  \
# 0                               19.529297                        2.106679
# 1                               19.369147                        2.353017
# 2                               19.167579                        2.416800
# 3                               15.978538                        2.262051
# 4                               19.199864                        2.277073
#
#    primary_cleaner.output.tail_ag  primary_cleaner.output.tail_pb  \
# 0                       14.936526                        2.534912
# 1                       16.250511                        3.049646
# 2                       16.491823                        3.124664
# 3                       16.024359                        2.960362
# 4                       16.480185                        3.112100
#
#    primary_cleaner.output.tail_sol  secondary_cleaner.state.floatbank2_a_air  \
# 0                         7.476074                                 25.853109
# 1                         6.733907                                 25.880539
# 2                         6.471768                                 26.005245
# 3                         6.843791                                 25.942508
# 4                         6.550154                                 26.024787
#
#    secondary_cleaner.state.floatbank2_a_level  \
# 0                                 -498.526489
# 1                                 -499.989656
# 2                                 -499.929616
# 3                                 -499.176749
# 4                                 -500.279091
#
#    secondary_cleaner.state.floatbank2_b_air  \
# 0                                 23.893660
# 1                                 23.889530
# 2                                 23.886657
# 3                                 23.955516
# 4                                 23.955345
#
#    secondary_cleaner.state.floatbank2_b_level  \
# 0                                 -501.406281
# 1                                 -500.372428
# 2                                 -499.951928
# 3                                 -499.848796
# 4                                 -500.593614
#
#    secondary_cleaner.state.floatbank3_a_air  \
# 0                                 23.961798
# 1                                 23.970550
# 2                                 23.913535
# 3                                 23.966838
# 4                                 23.985703
#
#    secondary_cleaner.state.floatbank3_a_level  \
# 0                                 -495.262817
# 1                                 -500.085473
# 2                                 -499.442343
# 3                                 -500.008812
# 4                                 -500.083811
#
#    secondary_cleaner.state.floatbank3_b_air  \
# 0                                 21.940409
# 1                                 22.085714
# 2                                 23.957717
# 3                                 23.954443
# 4                                 23.958945
#
#    secondary_cleaner.state.floatbank3_b_level  \
# 0                                 -499.340973
# 1                                 -499.446897
# 2                                 -499.901982
# 3                                 -499.944710
# 4                                 -499.990309
#
#    secondary_cleaner.state.floatbank4_a_air  \
# 0                                 14.016835
# 1                                 13.992281
# 2                                 14.015015
# 3                                 14.036510
# 4                                 14.027298
#
#    secondary_cleaner.state.floatbank4_a_level  \
# 0                                 -502.488007
# 1                                 -505.503262
# 2                                 -502.520901
# 3                                 -500.857308
# 4                                 -499.838632
#
#    secondary_cleaner.state.floatbank4_b_air  \
# 0                                 12.099931
# 1                                 11.950531
# 2                                 11.912783
# 3                                 11.999550
# 4                                 11.953070
#
#    secondary_cleaner.state.floatbank4_b_level  \
# 0                                 -504.715942
# 1                                 -501.331529
# 2                                 -501.133383
# 3                                 -501.193686
# 4                                 -501.053894
#
#    secondary_cleaner.state.floatbank5_a_air  \
# 0                                  9.925633
# 1                                 10.039245
# 2                                 10.070913
# 3                                  9.970366
# 4                                  9.925709
#
#    secondary_cleaner.state.floatbank5_a_level  \
# 0                                 -498.310211
# 1                                 -500.169983
# 2                                 -500.129135
# 3                                 -499.201640
# 4                                 -501.686727
#
#    secondary_cleaner.state.floatbank5_b_air  \
# 0                                  8.079666
# 1                                  7.984757
# 2                                  8.013877
# 3                                  7.977324
# 4                                  7.894242
#
#    secondary_cleaner.state.floatbank5_b_level  \
# 0                                 -500.470978
# 1                                 -500.582168
# 2                                 -500.517572
# 3                                 -500.255908
# 4                                 -500.356035
#
#    secondary_cleaner.state.floatbank6_a_air  \
# 0                                 14.151341
# 1                                 13.998353
# 2                                 14.028663
# 3                                 14.005551
# 4                                 13.996647
#
#    secondary_cleaner.state.floatbank6_a_level  \
# 0                                 -605.841980
# 1                                 -599.787184
# 2                                 -601.427363
# 3                                 -599.996129
# 4                                 -601.496691
#
#    secondary_cleaner.output.tail_au  secondary_cleaner.output.tail_ag  \
# 0                          2.606185                         14.500184
# 1                          2.488248                         14.265474
# 2                          2.458187                         14.115662
# 3                          2.322062                         13.732071
# 4                          2.330448                         14.079996
#
#    secondary_cleaner.output.tail_pb  secondary_cleaner.output.tail_sol  \
# 0                          4.694824                           8.764648
# 1                          4.592547                           9.001494
# 2                          4.624775                           8.842896
# 3                          4.482453                           9.122857
# 4                          4.470737                           8.871028
#
#    final.output.concentrate_au  final.output.concentrate_ag  \
# 0                    42.192020                     6.055403
# 1                    42.701629                     6.029369
# 2                    42.657501                     6.055926
# 3                    42.689819                     6.047977
# 4                    42.774141                     6.148599
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
#
#    final.output.recovery  final.output.tail_au  final.output.tail_ag  \
# 0              70.541216              2.143149             10.411962
# 1              69.266198              2.224930             10.462676
# 2              68.116445              2.257889             10.507046
# 3              68.347543              2.146849             10.422762
# 4              66.927016              2.055292             10.360302
#
#    final.output.tail_pb  final.output.tail_sol
# 0              0.895447              16.904297
# 1              0.927452              16.634514
# 2              0.953716              16.208849
# 3              0.883763              16.532835
# 4              0.792826              16.525686

# %%
display(df_train.info(),df_test.info(), df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14579 entries, 0 to 14578
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                14579 non-null  object
#  1   rougher.input.feed_au                               14579 non-null  float64
#  2   rougher.input.feed_ag                               14579 non-null  float64
#  3   rougher.input.feed_pb                               14507 non-null  float64
#  4   rougher.input.feed_sol                              14502 non-null  float64
#  5   rougher.input.feed_rate                             14572 non-null  float64
#  6   rougher.input.feed_size                             14478 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   14548 non-null  float64
#  8   rougher.input.floatbank10_xanthate                  14572 non-null  float64
#  9   rougher.state.floatbank10_a_air                     14579 non-null  float64
#  10  rougher.state.floatbank10_a_level                   14579 non-null  float64
#  11  rougher.state.floatbank10_b_air                     14579 non-null  float64
#  12  rougher.state.floatbank10_b_level                   14579 non-null  float64
#  13  rougher.state.floatbank10_c_air                     14579 non-null  float64
#  14  rougher.state.floatbank10_c_level                   14579 non-null  float64
#  15  rougher.state.floatbank10_d_air                     14579 non-null  float64
#  16  rougher.state.floatbank10_d_level                   14579 non-null  float64
#  17  rougher.state.floatbank10_e_air                     14150 non-null  float64
#  18  rougher.state.floatbank10_e_level                   14579 non-null  float64
#  19  rougher.state.floatbank10_f_air                     14579 non-null  float64
#  20  rougher.state.floatbank10_f_level                   14579 non-null  float64
#  21  rougher.input.floatbank11_sulfate                   14543 non-null  float64
#  22  rougher.input.floatbank11_xanthate                  14172 non-null  float64
#  23  rougher.calculation.sulfate_to_au_concentrate       14578 non-null  float64
#  24  rougher.calculation.floatbank10_sulfate_to_au_feed  14578 non-null  float64
#  25  rougher.calculation.floatbank11_sulfate_to_au_feed  14578 non-null  float64
#  26  rougher.calculation.au_pb_ratio                     14579 non-null  float64
#  27  rougher.output.concentrate_au                       14579 non-null  float64
#  28  rougher.output.concentrate_ag                       14579 non-null  float64
#  29  rougher.output.concentrate_pb                       14579 non-null  float64
#  30  rougher.output.concentrate_sol                      14561 non-null  float64
#  31  rougher.output.recovery                             14579 non-null  float64
#  32  rougher.output.tail_au                              14579 non-null  float64
#  33  rougher.output.tail_ag                              14578 non-null  float64
#  34  rougher.output.tail_pb                              14579 non-null  float64
#  35  rougher.output.tail_sol                             14579 non-null  float64
#  36  primary_cleaner.input.sulfate                       14556 non-null  float64
#  37  primary_cleaner.input.depressant                    14551 non-null  float64
#  38  primary_cleaner.input.feed_size                     14579 non-null  float64
#  39  primary_cleaner.input.xanthate                      14518 non-null  float64
#  40  primary_cleaner.state.floatbank8_a_air              14576 non-null  float64
#  41  primary_cleaner.state.floatbank8_a_level            14579 non-null  float64
#  42  primary_cleaner.state.floatbank8_b_air              14576 non-null  float64
#  43  primary_cleaner.state.floatbank8_b_level            14579 non-null  float64
#  44  primary_cleaner.state.floatbank8_c_air              14579 non-null  float64
#  45  primary_cleaner.state.floatbank8_c_level            14579 non-null  float64
#  46  primary_cleaner.state.floatbank8_d_air              14578 non-null  float64
#  47  primary_cleaner.state.floatbank8_d_level            14579 non-null  float64
#  48  primary_cleaner.output.concentrate_au               14579 non-null  float64
#  49  primary_cleaner.output.concentrate_ag               14579 non-null  float64
#  50  primary_cleaner.output.concentrate_pb               14491 non-null  float64
#  51  primary_cleaner.output.concentrate_sol              14314 non-null  float64
#  52  primary_cleaner.output.tail_au                      14579 non-null  float64
#  53  primary_cleaner.output.tail_ag                      14575 non-null  float64
#  54  primary_cleaner.output.tail_pb                      14573 non-null  float64
#  55  primary_cleaner.output.tail_sol                     14534 non-null  float64
#  56  secondary_cleaner.state.floatbank2_a_air            14485 non-null  float64
#  57  secondary_cleaner.state.floatbank2_a_level          14579 non-null  float64
#  58  secondary_cleaner.state.floatbank2_b_air            14557 non-null  float64
#  59  secondary_cleaner.state.floatbank2_b_level          14579 non-null  float64
#  60  secondary_cleaner.state.floatbank3_a_air            14567 non-null  float64
#  61  secondary_cleaner.state.floatbank3_a_level          14579 non-null  float64
#  62  secondary_cleaner.state.floatbank3_b_air            14579 non-null  float64
#  63  secondary_cleaner.state.floatbank3_b_level          14579 non-null  float64
#  64  secondary_cleaner.state.floatbank4_a_air            14574 non-null  float64
#  65  secondary_cleaner.state.floatbank4_a_level          14579 non-null  float64
#  66  secondary_cleaner.state.floatbank4_b_air            14579 non-null  float64
#  67  secondary_cleaner.state.floatbank4_b_level          14579 non-null  float64
#  68  secondary_cleaner.state.floatbank5_a_air            14579 non-null  float64
#  69  secondary_cleaner.state.floatbank5_a_level          14579 non-null  float64
#  70  secondary_cleaner.state.floatbank5_b_air            14579 non-null  float64
#  71  secondary_cleaner.state.floatbank5_b_level          14579 non-null  float64
#  72  secondary_cleaner.state.floatbank6_a_air            14578 non-null  float64
#  73  secondary_cleaner.state.floatbank6_a_level          14579 non-null  float64
#  74  secondary_cleaner.output.tail_au                    14579 non-null  float64
#  75  secondary_cleaner.output.tail_ag                    14578 non-null  float64
#  76  secondary_cleaner.output.tail_pb                    14575 non-null  float64
#  77  secondary_cleaner.output.tail_sol                   13659 non-null  float64
#  78  final.output.concentrate_au                         14579 non-null  float64
#  79  final.output.concentrate_ag                         14578 non-null  float64
#  80  final.output.concentrate_pb                         14578 non-null  float64
#  81  final.output.concentrate_sol                        14387 non-null  float64
#  82  final.output.recovery                               14579 non-null  float64
#  83  final.output.tail_au                                14579 non-null  float64
#  84  final.output.tail_ag                                14578 non-null  float64
#  85  final.output.tail_pb                                14504 non-null  float64
#  86  final.output.tail_sol                               14574 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 9.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4860 entries, 0 to 4859
# Data columns (total 53 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   date                                        4860 non-null   object
#  1   rougher.input.feed_au                       4860 non-null   float64
#  2   rougher.input.feed_ag                       4860 non-null   float64
#  3   rougher.input.feed_pb                       4832 non-null   float64
#  4   rougher.input.feed_sol                      4838 non-null   float64
#  5   rougher.input.feed_rate                     4856 non-null   float64
#  6   rougher.input.feed_size                     4816 non-null   float64
#  7   rougher.input.floatbank10_sulfate           4857 non-null   float64
#  8   rougher.input.floatbank10_xanthate          4859 non-null   float64
#  9   rougher.state.floatbank10_a_air             4859 non-null   float64
#  10  rougher.state.floatbank10_a_level           4859 non-null   float64
#  11  rougher.state.floatbank10_b_air             4859 non-null   float64
#  12  rougher.state.floatbank10_b_level           4859 non-null   float64
#  13  rougher.state.floatbank10_c_air             4859 non-null   float64
#  14  rougher.state.floatbank10_c_level           4859 non-null   float64
#  15  rougher.state.floatbank10_d_air             4860 non-null   float64
#  16  rougher.state.floatbank10_d_level           4860 non-null   float64
#  17  rougher.state.floatbank10_e_air             4853 non-null   float64
#  18  rougher.state.floatbank10_e_level           4860 non-null   float64
#  19  rougher.state.floatbank10_f_air             4860 non-null   float64
#  20  rougher.state.floatbank10_f_level           4860 non-null   float64
#  21  rougher.input.floatbank11_sulfate           4852 non-null   float64
#  22  rougher.input.floatbank11_xanthate          4814 non-null   float64
#  23  primary_cleaner.input.sulfate               4859 non-null   float64
#  24  primary_cleaner.input.depressant            4851 non-null   float64
#  25  primary_cleaner.input.feed_size             4860 non-null   float64
#  26  primary_cleaner.input.xanthate              4817 non-null   float64
#  27  primary_cleaner.state.floatbank8_a_air      4859 non-null   float64
#  28  primary_cleaner.state.floatbank8_a_level    4859 non-null   float64
#  29  primary_cleaner.state.floatbank8_b_air      4859 non-null   float64
#  30  primary_cleaner.state.floatbank8_b_level    4859 non-null   float64
#  31  primary_cleaner.state.floatbank8_c_air      4858 non-null   float64
#  32  primary_cleaner.state.floatbank8_c_level    4859 non-null   float64
#  33  primary_cleaner.state.floatbank8_d_air      4858 non-null   float64
#  34  primary_cleaner.state.floatbank8_d_level    4859 non-null   float64
#  35  secondary_cleaner.state.floatbank2_a_air    4734 non-null   float64
#  36  secondary_cleaner.state.floatbank2_a_level  4859 non-null   float64
#  37  secondary_cleaner.state.floatbank2_b_air    4859 non-null   float64
#  38  secondary_cleaner.state.floatbank2_b_level  4859 non-null   float64
#  39  secondary_cleaner.state.floatbank3_a_air    4859 non-null   float64
#  40  secondary_cleaner.state.floatbank3_a_level  4859 non-null   float64
#  41  secondary_cleaner.state.floatbank3_b_air    4859 non-null   float64
#  42  secondary_cleaner.state.floatbank3_b_level  4859 non-null   float64
#  43  secondary_cleaner.state.floatbank4_a_air    4859 non-null   float64
#  44  secondary_cleaner.state.floatbank4_a_level  4859 non-null   float64
#  45  secondary_cleaner.state.floatbank4_b_air    4859 non-null   float64
#  46  secondary_cleaner.state.floatbank4_b_level  4859 non-null   float64
#  47  secondary_cleaner.state.floatbank5_a_air    4859 non-null   float64
#  48  secondary_cleaner.state.floatbank5_a_level  4859 non-null   float64
#  49  secondary_cleaner.state.floatbank5_b_air    4859 non-null   float64
#  50  secondary_cleaner.state.floatbank5_b_level  4859 non-null   float64
#  51  secondary_cleaner.state.floatbank6_a_air    4859 non-null   float64
#  52  secondary_cleaner.state.floatbank6_a_level  4859 non-null   float64
# dtypes: float64(52), object(1)
# memory usage: 2.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 87 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   date                                                19439 non-null  object
#  1   rougher.input.feed_au                               19439 non-null  float64
#  2   rougher.input.feed_ag                               19439 non-null  float64
#  3   rougher.input.feed_pb                               19339 non-null  float64
#  4   rougher.input.feed_sol                              19340 non-null  float64
#  5   rougher.input.feed_rate                             19428 non-null  float64
#  6   rougher.input.feed_size                             19294 non-null  float64
#  7   rougher.input.floatbank10_sulfate                   19405 non-null  float64
#  8   rougher.input.floatbank10_xanthate                  19431 non-null  float64
#  9   rougher.state.floatbank10_a_air                     19438 non-null  float64
#  10  rougher.state.floatbank10_a_level                   19438 non-null  float64
#  11  rougher.state.floatbank10_b_air                     19438 non-null  float64
#  12  rougher.state.floatbank10_b_level                   19438 non-null  float64
#  13  rougher.state.floatbank10_c_air                     19438 non-null  float64
#  14  rougher.state.floatbank10_c_level                   19438 non-null  float64
#  15  rougher.state.floatbank10_d_air                     19439 non-null  float64
#  16  rougher.state.floatbank10_d_level                   19439 non-null  float64
#  17  rougher.state.floatbank10_e_air                     19003 non-null  float64
#  18  rougher.state.floatbank10_e_level                   19439 non-null  float64
#  19  rougher.state.floatbank10_f_air                     19439 non-null  float64
#  20  rougher.state.floatbank10_f_level                   19439 non-null  float64
#  21  rougher.input.floatbank11_sulfate                   19395 non-null  float64
#  22  rougher.input.floatbank11_xanthate                  18986 non-null  float64
#  23  rougher.calculation.sulfate_to_au_concentrate       19437 non-null  float64
#  24  rougher.calculation.floatbank10_sulfate_to_au_feed  19437 non-null  float64
#  25  rougher.calculation.floatbank11_sulfate_to_au_feed  19437 non-null  float64
#  26  rougher.calculation.au_pb_ratio                     19439 non-null  float64
#  27  rougher.output.concentrate_au                       19439 non-null  float64
#  28  rougher.output.concentrate_ag                       19439 non-null  float64
#  29  rougher.output.concentrate_pb                       19439 non-null  float64
#  30  rougher.output.concentrate_sol                      19416 non-null  float64
#  31  rougher.output.recovery                             19439 non-null  float64
#  32  rougher.output.tail_au                              19439 non-null  float64
#  33  rougher.output.tail_ag                              19438 non-null  float64
#  34  rougher.output.tail_pb                              19439 non-null  float64
#  35  rougher.output.tail_sol                             19439 non-null  float64
#  36  primary_cleaner.input.sulfate                       19415 non-null  float64
#  37  primary_cleaner.input.depressant                    19402 non-null  float64
#  38  primary_cleaner.input.feed_size                     19439 non-null  float64
#  39  primary_cleaner.input.xanthate                      19335 non-null  float64
#  40  primary_cleaner.state.floatbank8_a_air              19435 non-null  float64
#  41  primary_cleaner.state.floatbank8_a_level            19438 non-null  float64
#  42  primary_cleaner.state.floatbank8_b_air              19435 non-null  float64
#  43  primary_cleaner.state.floatbank8_b_level            19438 non-null  float64
#  44  primary_cleaner.state.floatbank8_c_air              19437 non-null  float64
#  45  primary_cleaner.state.floatbank8_c_level            19438 non-null  float64
#  46  primary_cleaner.state.floatbank8_d_air              19436 non-null  float64
#  47  primary_cleaner.state.floatbank8_d_level            19438 non-null  float64
#  48  primary_cleaner.output.concentrate_au               19439 non-null  float64
#  49  primary_cleaner.output.concentrate_ag               19439 non-null  float64
#  50  primary_cleaner.output.concentrate_pb               19323 non-null  float64
#  51  primary_cleaner.output.concentrate_sol              19069 non-null  float64
#  52  primary_cleaner.output.tail_au                      19439 non-null  float64
#  53  primary_cleaner.output.tail_ag                      19435 non-null  float64
#  54  primary_cleaner.output.tail_pb                      19418 non-null  float64
#  55  primary_cleaner.output.tail_sol                     19377 non-null  float64
#  56  secondary_cleaner.state.floatbank2_a_air            19219 non-null  float64
#  57  secondary_cleaner.state.floatbank2_a_level          19438 non-null  float64
#  58  secondary_cleaner.state.floatbank2_b_air            19416 non-null  float64
#  59  secondary_cleaner.state.floatbank2_b_level          19438 non-null  float64
#  60  secondary_cleaner.state.floatbank3_a_air            19426 non-null  float64
#  61  secondary_cleaner.state.floatbank3_a_level          19438 non-null  float64
#  62  secondary_cleaner.state.floatbank3_b_air            19438 non-null  float64
#  63  secondary_cleaner.state.floatbank3_b_level          19438 non-null  float64
#  64  secondary_cleaner.state.floatbank4_a_air            19433 non-null  float64
#  65  secondary_cleaner.state.floatbank4_a_level          19438 non-null  float64
#  66  secondary_cleaner.state.floatbank4_b_air            19438 non-null  float64
#  67  secondary_cleaner.state.floatbank4_b_level          19438 non-null  float64
#  68  secondary_cleaner.state.floatbank5_a_air            19438 non-null  float64
#  69  secondary_cleaner.state.floatbank5_a_level          19438 non-null  float64
#  70  secondary_cleaner.state.floatbank5_b_air            19438 non-null  float64
#  71  secondary_cleaner.state.floatbank5_b_level          19438 non-null  float64
#  72  secondary_cleaner.state.floatbank6_a_air            19437 non-null  float64
#  73  secondary_cleaner.state.floatbank6_a_level          19438 non-null  float64
#  74  secondary_cleaner.output.tail_au                    19439 non-null  float64
#  75  secondary_cleaner.output.tail_ag                    19437 non-null  float64
#  76  secondary_cleaner.output.tail_pb                    19427 non-null  float64
#  77  secondary_cleaner.output.tail_sol                   17691 non-null  float64
#  78  final.output.concentrate_au                         19439 non-null  float64
#  79  final.output.concentrate_ag                         19438 non-null  float64
#  80  final.output.concentrate_pb                         19438 non-null  float64
#  81  final.output.concentrate_sol                        19228 non-null  float64
#  82  final.output.recovery                               19439 non-null  float64
#  83  final.output.tail_au                                19439 non-null  float64
#  84  final.output.tail_ag                                19438 non-null  float64
#  85  final.output.tail_pb                                19338 non-null  float64
#  86  final.output.tail_sol                               19433 non-null  float64
# dtypes: float64(86), object(1)
# memory usage: 12.9+ MB
# None
# None
# None

# %% [markdown]
# **Описание данных**
#
# **Технологический процесс**
# - Rougher feed — исходное сырье
# - Rougher additions (или reagent additions) — флотационные реагенты: Xanthate, Sulphate, Depressant
# - Xanthate — ксантогенат (промотер, или активатор флотации);
# - Sulphate — сульфат (на данном производстве сульфид натрия);
# - Depressant — депрессант (силикат натрия).
# - Rougher process (англ. «грубый процесс») — флотация
# - Rougher tails — отвальные хвосты
# - Float banks — флотационная установка
# - Cleaner process — очистка
# - Rougher Au — черновой концентрат золота
# - Final Au — финальный концентрат золота
#
# **Параметры этапов**
# - air amount — объём воздуха
# - fluid levels — уровень жидкости
# - feed size — размер гранул сырья
# - feed rate — скорость подачи
#
# **Наименование признаков**
#
# **Наименование признаков должно быть такое:**
# ``[этап].[тип_параметра].[название_параметра]``
#
# **Пример:**
# ``rougher.input.feed_ag``
#
# **Возможные значения для блока [этап]:**
# - rougher — флотация
# - primary_cleaner — первичная очистка
# - secondary_cleaner — вторичная очистка
# - final — финальные характеристики
#
# **Возможные значения для блока [тип_параметра]:**
# - input — параметры сырья
# - output — параметры продукта
# - state — параметры, характеризующие текущее состояние этапа
# - calculation — расчётные характеристики

# %% [markdown]
# Исходные данные ``df`` и обучающая выборка ``df_train`` содержат 87 столбцов, тестовая выборка ``df_test`` - 53 столбца.

# %%
df_list=[df, df_train, df_test]
df_list_name = ['"Исходные данные"', '"Обучающая выборка"', '"Тестовая выборка"']

# %%
for i,j in zip(df_list,df_list_name):
    print('Количество пропущеных данных в солбцах датасета',j)
    print(i.isna().sum()[i.isna().sum() > 0].to_string())
    print()
# Out:
# Количество пропущеных данных в солбцах датасета "Исходные данные"
# rougher.input.feed_pb                                  100
# rougher.input.feed_sol                                  99
# rougher.input.feed_rate                                 11
# rougher.input.feed_size                                145
# rougher.input.floatbank10_sulfate                       34
# rougher.input.floatbank10_xanthate                       8
# rougher.state.floatbank10_a_air                          1
# rougher.state.floatbank10_a_level                        1
# rougher.state.floatbank10_b_air                          1
# rougher.state.floatbank10_b_level                        1
# rougher.state.floatbank10_c_air                          1
# rougher.state.floatbank10_c_level                        1
# rougher.state.floatbank10_e_air                        436
# rougher.input.floatbank11_sulfate                       44
# rougher.input.floatbank11_xanthate                     453
# rougher.calculation.sulfate_to_au_concentrate            2
# rougher.calculation.floatbank10_sulfate_to_au_feed       2
# rougher.calculation.floatbank11_sulfate_to_au_feed       2
# rougher.output.concentrate_sol                          23
# rougher.output.tail_ag                                   1
# primary_cleaner.input.sulfate                           24
# primary_cleaner.input.depressant                        37
# primary_cleaner.input.xanthate                         104
# primary_cleaner.state.floatbank8_a_air                   4
# primary_cleaner.state.floatbank8_a_level                 1
# primary_cleaner.state.floatbank8_b_air                   4
# primary_cleaner.state.floatbank8_b_level                 1
# primary_cleaner.state.floatbank8_c_air                   2
# primary_cleaner.state.floatbank8_c_level                 1
# primary_cleaner.state.floatbank8_d_air                   3
# primary_cleaner.state.floatbank8_d_level                 1
# primary_cleaner.output.concentrate_pb                  116
# primary_cleaner.output.concentrate_sol                 370
# primary_cleaner.output.tail_ag                           4
# primary_cleaner.output.tail_pb                          21
# primary_cleaner.output.tail_sol                         62
# secondary_cleaner.state.floatbank2_a_air               220
# secondary_cleaner.state.floatbank2_a_level               1
# secondary_cleaner.state.floatbank2_b_air                23
# secondary_cleaner.state.floatbank2_b_level               1
# secondary_cleaner.state.floatbank3_a_air                13
# secondary_cleaner.state.floatbank3_a_level               1
# secondary_cleaner.state.floatbank3_b_air                 1
# secondary_cleaner.state.floatbank3_b_level               1
# secondary_cleaner.state.floatbank4_a_air                 6
# secondary_cleaner.state.floatbank4_a_level               1
# secondary_cleaner.state.floatbank4_b_air                 1
# secondary_cleaner.state.floatbank4_b_level               1
# secondary_cleaner.state.floatbank5_a_air                 1
# secondary_cleaner.state.floatbank5_a_level               1
# secondary_cleaner.state.floatbank5_b_air                 1
# secondary_cleaner.state.floatbank5_b_level               1
# secondary_cleaner.state.floatbank6_a_air                 2
# secondary_cleaner.state.floatbank6_a_level               1
# secondary_cleaner.output.tail_ag                         2
# secondary_cleaner.output.tail_pb                        12
# secondary_cleaner.output.tail_sol                     1748
# final.output.concentrate_ag                              1
# final.output.concentrate_pb                              1
# final.output.concentrate_sol                           211
# final.output.tail_ag                                     1
# final.output.tail_pb                                   101
# final.output.tail_sol                                    6
#
# Количество пропущеных данных в солбцах датасета "Обучающая выборка"
# rougher.input.feed_pb                                  72
# rougher.input.feed_sol                                 77
# rougher.input.feed_rate                                 7
# rougher.input.feed_size                               101
# rougher.input.floatbank10_sulfate                      31
# rougher.input.floatbank10_xanthate                      7
# rougher.state.floatbank10_e_air                       429
# rougher.input.floatbank11_sulfate                      36
# rougher.input.floatbank11_xanthate                    407
# rougher.calculation.sulfate_to_au_concentrate           1
# rougher.calculation.floatbank10_sulfate_to_au_feed      1
# rougher.calculation.floatbank11_sulfate_to_au_feed      1
# rougher.output.concentrate_sol                         18
# rougher.output.tail_ag                                  1
# primary_cleaner.input.sulfate                          23
# primary_cleaner.input.depressant                       28
# primary_cleaner.input.xanthate                         61
# primary_cleaner.state.floatbank8_a_air                  3
# primary_cleaner.state.floatbank8_b_air                  3
# primary_cleaner.state.floatbank8_d_air                  1
# primary_cleaner.output.concentrate_pb                  88
# primary_cleaner.output.concentrate_sol                265
# primary_cleaner.output.tail_ag                          4
# primary_cleaner.output.tail_pb                          6
# primary_cleaner.output.tail_sol                        45
# secondary_cleaner.state.floatbank2_a_air               94
# secondary_cleaner.state.floatbank2_b_air               22
# secondary_cleaner.state.floatbank3_a_air               12
# secondary_cleaner.state.floatbank4_a_air                5
# secondary_cleaner.state.floatbank6_a_air                1
# secondary_cleaner.output.tail_ag                        1
# secondary_cleaner.output.tail_pb                        4
# secondary_cleaner.output.tail_sol                     920
# final.output.concentrate_ag                             1
# final.output.concentrate_pb                             1
# final.output.concentrate_sol                          192
# final.output.tail_ag                                    1
# final.output.tail_pb                                   75
# final.output.tail_sol                                   5
#
# Количество пропущеных данных в солбцах датасета "Тестовая выборка"
# rougher.input.feed_pb                          28
# rougher.input.feed_sol                         22
# rougher.input.feed_rate                         4
# rougher.input.feed_size                        44
# rougher.input.floatbank10_sulfate               3
# rougher.input.floatbank10_xanthate              1
# rougher.state.floatbank10_a_air                 1
# rougher.state.floatbank10_a_level               1
# rougher.state.floatbank10_b_air                 1
# rougher.state.floatbank10_b_level               1
# rougher.state.floatbank10_c_air                 1
# rougher.state.floatbank10_c_level               1
# rougher.state.floatbank10_e_air                 7
# rougher.input.floatbank11_sulfate               8
# rougher.input.floatbank11_xanthate             46
# primary_cleaner.input.sulfate                   1
# primary_cleaner.input.depressant                9
# primary_cleaner.input.xanthate                 43
# primary_cleaner.state.floatbank8_a_air          1
# primary_cleaner.state.floatbank8_a_level        1
# primary_cleaner.state.floatbank8_b_air          1
# primary_cleaner.state.floatbank8_b_level        1
# primary_cleaner.state.floatbank8_c_air          2
# primary_cleaner.state.floatbank8_c_level        1
# primary_cleaner.state.floatbank8_d_air          2
# primary_cleaner.state.floatbank8_d_level        1
# secondary_cleaner.state.floatbank2_a_air      126
# secondary_cleaner.state.floatbank2_a_level      1
# secondary_cleaner.state.floatbank2_b_air        1
# secondary_cleaner.state.floatbank2_b_level      1
# secondary_cleaner.state.floatbank3_a_air        1
# secondary_cleaner.state.floatbank3_a_level      1
# secondary_cleaner.state.floatbank3_b_air        1
# secondary_cleaner.state.floatbank3_b_level      1
# secondary_cleaner.state.floatbank4_a_air        1
# secondary_cleaner.state.floatbank4_a_level      1
# secondary_cleaner.state.floatbank4_b_air        1
# secondary_cleaner.state.floatbank4_b_level      1
# secondary_cleaner.state.floatbank5_a_air        1
# secondary_cleaner.state.floatbank5_a_level      1
# secondary_cleaner.state.floatbank5_b_air        1
# secondary_cleaner.state.floatbank5_b_level      1
# secondary_cleaner.state.floatbank6_a_air        1
# secondary_cleaner.state.floatbank6_a_level      1

# %%
for i,j in zip(df_list,df_list_name):
    print(f'Дубликатов в датасете {j} - {i.duplicated().sum()}')
# Out:
# Дубликатов в датасете "Исходные данные" - 0
# Дубликатов в датасете "Обучающая выборка" - 0
# Дубликатов в датасете "Тестовая выборка" - 0

# %% [markdown]
# **Вывод**
#
# - Исходный датасет df содежит 19439 строк и 87 столбцов. Размер обучающей выборки df_train - (14149, 87). В тестовой выборке df_test отсутствуют 34 столбца с данными и ее размер - (5290, 53).
# - Типы данных - float64 для всех столбцов, кроме date - типа object.
# - В каждой выборке имеются пропущенные значения.
# - Полных дубликатов в данных не обнаружено.

# %% [markdown]
# ### Проверка расчета эффективности обогащения

# %% [markdown]
# Эффективность обогащения рассчитывается по формуле
#
# ``Recovery = (C * (F - T)) / (F * (C - T)) * 100``
#
# где:
# - C — доля золота в концентрате после флотации/очистки;
# - F — доля золота в сырье/концентрате до флотации/очистки;
# - T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %%
def recovery(C, F, T, true_recovery):
    
    calc = pd.Series((C * (F - T)) / (F * (C - T)) * 100)  
    
    mae = mean_absolute_error(true_recovery, calc) 
    
    
    return print('Средняя абсолютная ошибка равна', mae)

# %%
recovery(C=df_train['rougher.output.concentrate_au'], 
         F=df_train['rougher.input.feed_au'], 
         T=df_train['rougher.output.tail_au'],
        true_recovery=df_train['rougher.output.recovery'])
# Out:
# Средняя абсолютная ошибка равна 9.83758577644259e-15

# %% [markdown]
# **Вывод**

# %% [markdown]
# Средняя абсолютная ошибка  составила 9.83758577644259e-15
# Ошибка близка к 0, это значит, что эффективность обогащения ``rougher.output.recovery`` в обучающей выборке рассчитана верно.

# %% [markdown]
# **Проанализируем признаки, недоступные в тестовой выборке.**

# %%
columns=list(set(df.columns)-set(df_test.columns))

df[columns].reindex(sorted(df[columns].columns), axis=1).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19439 entries, 0 to 19438
# Data columns (total 34 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         19438 non-null  float64
#  1   final.output.concentrate_au                         19439 non-null  float64
#  2   final.output.concentrate_pb                         19438 non-null  float64
#  3   final.output.concentrate_sol                        19228 non-null  float64
#  4   final.output.recovery                               19439 non-null  float64
#  5   final.output.tail_ag                                19438 non-null  float64
#  6   final.output.tail_au                                19439 non-null  float64
#  7   final.output.tail_pb                                19338 non-null  float64
#  8   final.output.tail_sol                               19433 non-null  float64
#  9   primary_cleaner.output.concentrate_ag               19439 non-null  float64
#  10  primary_cleaner.output.concentrate_au               19439 non-null  float64
#  11  primary_cleaner.output.concentrate_pb               19323 non-null  float64
#  12  primary_cleaner.output.concentrate_sol              19069 non-null  float64
#  13  primary_cleaner.output.tail_ag                      19435 non-null  float64
#  14  primary_cleaner.output.tail_au                      19439 non-null  float64
#  15  primary_cleaner.output.tail_pb                      19418 non-null  float64
#  16  primary_cleaner.output.tail_sol                     19377 non-null  float64
#  17  rougher.calculation.au_pb_ratio                     19439 non-null  float64
#  18  rougher.calculation.floatbank10_sulfate_to_au_feed  19437 non-null  float64
#  19  rougher.calculation.floatbank11_sulfate_to_au_feed  19437 non-null  float64
#  20  rougher.calculation.sulfate_to_au_concentrate       19437 non-null  float64
#  21  rougher.output.concentrate_ag                       19439 non-null  float64
#  22  rougher.output.concentrate_au                       19439 non-null  float64
#  23  rougher.output.concentrate_pb                       19439 non-null  float64
#  24  rougher.output.concentrate_sol                      19416 non-null  float64
#  25  rougher.output.recovery                             19439 non-null  float64
#  26  rougher.output.tail_ag                              19438 non-null  float64
#  27  rougher.output.tail_au                              19439 non-null  float64
#  28  rougher.output.tail_pb                              19439 non-null  float64
#  29  rougher.output.tail_sol                             19439 non-null  float64
#  30  secondary_cleaner.output.tail_ag                    19437 non-null  float64
#  31  secondary_cleaner.output.tail_au                    19439 non-null  float64
#  32  secondary_cleaner.output.tail_pb                    19427 non-null  float64
#  33  secondary_cleaner.output.tail_sol                   17691 non-null  float64
# dtypes: float64(34)
# memory usage: 5.0 MB

# %% [markdown]
# В тестовой выборке отсутсвуют 34 параметра и целевые признаки. Все параметры имееют тип данных ``float``
#
# Наименование признаков:

# %% [markdown]
# - ``final.output`` финальные характеристики параметра продукта
# - ``primary_cleaner.output`` первичная очистка параметра продукта
# - ``rougher.calculation``  флотация расчётные характеристики
# - ``rougher.output`` флотация параметра продукта
# - ``secondary_cleaner.output`` вторичная очистка параметра продукта
# - ``final.output.recovery`` Эффективность обогащения

# %% [markdown]
# В тестовой выборке отсутствуют два целевых признака - ``final.output.recovery``, ``rougher.output.recovery``. Их необходимо найти из данных по дате и добавить.
# Некоторые признаки могут быть недоступны в test, потому что они не могут быть измерены в реальном времени в процессе работы модели. Признаки с маркировкой output- это признаки, которые получают после обработки сырья на каждом этапе, до обработки и прохождения очередного этапа они нам не известны
# Из обучающей выборки необходимо удалить остальные столбцы, которые отсуствуют в тестовой выборке.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# **Дополним тестовую выборку целевыми признаками**

# %%
print('Размер тестовой выборки до добавления целевых признаков', df_test.shape)
# Out:
# Размер тестовой выборки до добавления целевых признаков (4860, 53)

# %%
df_test = df_test.merge(df[['date', 'final.output.recovery', 'rougher.output.recovery']], on='date', how='left')

# %%
print('Размер тестовой выборки до добавления целевых признаков', df_test.shape)
# Out:
# Размер тестовой выборки до добавления целевых признаков (4860, 55)

# %% [markdown]
# **Удалим в обучающей выборке признаки которых нет в тестовой выборке**

# %%
print('Размер обучающей выборки до удаления признаков', df_train.shape)
# Out:
# Размер обучающей выборки до удаления признаков (14579, 87)

# %%
# удалим целевые признаки из списка отсутсвующих признаков в тестовой выборке
columns.remove('rougher.output.recovery') 
columns.remove('final.output.recovery')

# %%
df_train = df_train.drop(columns, axis=1)

# %%
print('Размер обучающей выборки до удаления признаков', df_train.shape)
# Out:
# Размер обучающей выборки до удаления признаков (14579, 55)

# %% [markdown]
# **Заполним пропуски**

# %% [markdown]
# Т.К. данные индексируются датой и временем получения информации они распределены по времени. Значит, стоит заполнить пропуски значением из прошлой строки.

# %%
column_nan= list(df.columns[df.isnull().any()]) # Находим столбцы с пустыми значениями

# %%
print('Количество стобцов с пропусками:',len(column_nan))
# Out:
# Количество стобцов с пропусками: 63

# %%
pd.set_option('display.max_rows', None)
df[column_nan].describe().T
# Out:
#                                                       count          mean  \
# rougher.input.feed_pb                               19339.0      3.598085
# rougher.input.feed_sol                              19340.0     36.695114
# rougher.input.feed_rate                             19428.0    478.320042
# rougher.input.feed_size                             19294.0     58.970310
# rougher.input.floatbank10_sulfate                   19405.0     12.334373
# rougher.input.floatbank10_xanthate                  19431.0      6.021474
# rougher.state.floatbank10_a_air                     19438.0   1105.315068
# rougher.state.floatbank10_a_level                   19438.0   -376.610690
# rougher.state.floatbank10_b_air                     19438.0   1320.221139
# rougher.state.floatbank10_b_level                   19438.0   -467.247826
# rougher.state.floatbank10_c_air                     19438.0   1299.968799
# rougher.state.floatbank10_c_level                   19438.0   -467.716946
# rougher.state.floatbank10_e_air                     19003.0   1080.869685
# rougher.input.floatbank11_sulfate                   19395.0     12.064140
# rougher.input.floatbank11_xanthate                  18986.0      6.065533
# rougher.calculation.sulfate_to_au_concentrate       19437.0  42171.189025
# rougher.calculation.floatbank10_sulfate_to_au_feed  19437.0   3393.052498
# rougher.calculation.floatbank11_sulfate_to_au_feed  19437.0   3256.854171
# rougher.output.concentrate_sol                      19416.0     28.805571
# rougher.output.tail_ag                              19438.0      5.588982
# primary_cleaner.input.sulfate                       19415.0    144.624774
# primary_cleaner.input.depressant                    19402.0      8.817039
# primary_cleaner.input.xanthate                      19335.0      1.021795
# primary_cleaner.state.floatbank8_a_air              19435.0   1589.353532
# primary_cleaner.state.floatbank8_a_level            19438.0   -491.195012
# primary_cleaner.state.floatbank8_b_air              19435.0   1591.344175
# primary_cleaner.state.floatbank8_b_level            19438.0   -492.192978
# primary_cleaner.state.floatbank8_c_air              19437.0   1586.669124
# primary_cleaner.state.floatbank8_c_level            19438.0   -491.980070
# primary_cleaner.state.floatbank8_d_air              19436.0   1542.912418
# primary_cleaner.state.floatbank8_d_level            19438.0   -488.017382
# primary_cleaner.output.concentrate_pb               19323.0      9.829530
# primary_cleaner.output.concentrate_sol              19069.0     10.489499
# primary_cleaner.output.tail_ag                      19435.0     16.145826
# primary_cleaner.output.tail_pb                      19418.0      3.435656
# primary_cleaner.output.tail_sol                     19377.0      7.973209
# secondary_cleaner.state.floatbank2_a_air            19219.0     28.705564
# secondary_cleaner.state.floatbank2_a_level          19438.0   -502.367331
# secondary_cleaner.state.floatbank2_b_air            19416.0     24.106800
# secondary_cleaner.state.floatbank2_b_level          19438.0   -503.230712
# secondary_cleaner.state.floatbank3_a_air            19426.0     28.199338
# secondary_cleaner.state.floatbank3_a_level          19438.0   -486.203350
# secondary_cleaner.state.floatbank3_b_air            19438.0     22.200645
# secondary_cleaner.state.floatbank3_b_level          19438.0   -493.742107
# secondary_cleaner.state.floatbank4_a_air            19433.0     18.987674
# secondary_cleaner.state.floatbank4_a_level          19438.0   -485.894516
# secondary_cleaner.state.floatbank4_b_air            19438.0     15.010366
# secondary_cleaner.state.floatbank4_b_level          19438.0   -461.078636
# secondary_cleaner.state.floatbank5_a_air            19438.0     15.694452
# secondary_cleaner.state.floatbank5_a_level          19438.0   -488.684065
# secondary_cleaner.state.floatbank5_b_air            19438.0     12.198224
# secondary_cleaner.state.floatbank5_b_level          19438.0   -487.149827
# secondary_cleaner.state.floatbank6_a_air            19437.0     18.959024
# secondary_cleaner.state.floatbank6_a_level          19438.0   -505.436305
# secondary_cleaner.output.tail_ag                    19437.0     14.586833
# secondary_cleaner.output.tail_pb                    19427.0      5.777703
# secondary_cleaner.output.tail_sol                   17691.0      7.167247
# final.output.concentrate_ag                         19438.0      5.168470
# final.output.concentrate_pb                         19438.0      9.978895
# final.output.concentrate_sol                        19228.0      9.501224
# final.output.tail_ag                                19438.0      9.688589
# final.output.tail_pb                                19338.0      2.705795
# final.output.tail_sol                               19433.0     10.583728
#
#                                                               std  \
# rougher.input.feed_pb                                    1.049486
# rougher.input.feed_sol                                   5.145445
# rougher.input.feed_rate                                105.373758
# rougher.input.feed_size                                 21.634478
# rougher.input.floatbank10_sulfate                        3.427317
# rougher.input.floatbank10_xanthate                       1.127263
# rougher.state.floatbank10_a_air                        160.826798
# rougher.state.floatbank10_a_level                       93.909667
# rougher.state.floatbank10_b_air                        176.287095
# rougher.state.floatbank10_b_level                       54.673142
# rougher.state.floatbank10_c_air                        202.804325
# rougher.state.floatbank10_c_level                       53.534825
# rougher.state.floatbank10_e_air                        172.149992
# rougher.input.floatbank11_sulfate                        3.784221
# rougher.input.floatbank11_xanthate                       1.099118
# rougher.calculation.sulfate_to_au_concentrate       324362.111569
# rougher.calculation.floatbank10_sulfate_to_au_feed    4943.845943
# rougher.calculation.floatbank11_sulfate_to_au_feed    5781.423659
# rougher.output.concentrate_sol                           5.944207
# rougher.output.tail_ag                                   1.111288
# primary_cleaner.input.sulfate                           44.464071
# primary_cleaner.input.depressant                         3.286186
# primary_cleaner.input.xanthate                           0.513254
# primary_cleaner.state.floatbank8_a_air                 128.996838
# primary_cleaner.state.floatbank8_a_level                32.431842
# primary_cleaner.state.floatbank8_b_air                 131.810879
# primary_cleaner.state.floatbank8_b_level                33.794822
# primary_cleaner.state.floatbank8_c_air                 136.111402
# primary_cleaner.state.floatbank8_c_level                32.711455
# primary_cleaner.state.floatbank8_d_air                 246.199602
# primary_cleaner.state.floatbank8_d_level                43.959780
# primary_cleaner.output.concentrate_pb                    2.556843
# primary_cleaner.output.concentrate_sol                   3.909639
# primary_cleaner.output.tail_ag                           3.548598
# primary_cleaner.output.tail_pb                           1.392536
# primary_cleaner.output.tail_sol                          2.212677
# secondary_cleaner.state.floatbank2_a_air                 5.458789
# secondary_cleaner.state.floatbank2_a_level              53.571950
# secondary_cleaner.state.floatbank2_b_air                 5.749616
# secondary_cleaner.state.floatbank2_b_level              56.567724
# secondary_cleaner.state.floatbank3_a_air                 6.134908
# secondary_cleaner.state.floatbank3_a_level              54.412349
# secondary_cleaner.state.floatbank3_b_air                 5.574001
# secondary_cleaner.state.floatbank3_b_level              43.372158
# secondary_cleaner.state.floatbank4_a_air                 5.411058
# secondary_cleaner.state.floatbank4_a_level              47.758570
# secondary_cleaner.state.floatbank4_b_air                 4.890228
# secondary_cleaner.state.floatbank4_b_level              67.405524
# secondary_cleaner.state.floatbank5_a_air                 5.510974
# secondary_cleaner.state.floatbank5_a_level              34.533396
# secondary_cleaner.state.floatbank5_b_air                 5.333024
# secondary_cleaner.state.floatbank5_b_level              38.347312
# secondary_cleaner.state.floatbank6_a_air                 5.550498
# secondary_cleaner.state.floatbank6_a_level              37.689057
# secondary_cleaner.output.tail_ag                         4.265202
# secondary_cleaner.output.tail_pb                         2.774598
# secondary_cleaner.output.tail_sol                        3.916079
# final.output.concentrate_ag                              1.372348
# final.output.concentrate_pb                              1.669240
# final.output.concentrate_sol                             2.787537
# final.output.tail_ag                                     2.328642
# final.output.tail_pb                                     0.949077
# final.output.tail_sol                                    2.868782
#
#                                                              min  \
# rougher.input.feed_pb                               1.000000e-02
# rougher.input.feed_sol                              1.000000e-02
# rougher.input.feed_rate                             2.985849e-03
# rougher.input.feed_size                             4.636880e-02
# rougher.input.floatbank10_sulfate                   1.083112e-03
# rougher.input.floatbank10_xanthate                  5.682328e-04
# rougher.state.floatbank10_a_air                    -4.206929e-02
# rougher.state.floatbank10_a_level                  -6.579498e+02
# rougher.state.floatbank10_b_air                    -7.218064e-01
# rougher.state.floatbank10_b_level                  -6.502600e+02
# rougher.state.floatbank10_c_air                    -5.663551e-02
# rougher.state.floatbank10_c_level                  -6.475444e+02
# rougher.state.floatbank10_e_air                    -1.982295e+00
# rougher.input.floatbank11_sulfate                   7.673764e-05
# rougher.input.floatbank11_xanthate                  2.904126e-04
# rougher.calculation.sulfate_to_au_concentrate      -4.223520e+07
# rougher.calculation.floatbank10_sulfate_to_au_feed -4.865987e+02
# rougher.calculation.floatbank11_sulfate_to_au_feed -2.649828e+02
# rougher.output.concentrate_sol                      0.000000e+00
# rougher.output.tail_ag                              5.945623e-01
# primary_cleaner.input.sulfate                       3.111820e-03
# primary_cleaner.input.depressant                    0.000000e+00
# primary_cleaner.input.xanthate                      4.632753e-06
# primary_cleaner.state.floatbank8_a_air              5.445860e-32
# primary_cleaner.state.floatbank8_a_level           -7.986417e+02
# primary_cleaner.state.floatbank8_b_air              6.647490e-32
# primary_cleaner.state.floatbank8_b_level           -7.999970e+02
# primary_cleaner.state.floatbank8_c_air              4.033736e-32
# primary_cleaner.state.floatbank8_c_level           -7.999606e+02
# primary_cleaner.state.floatbank8_d_air              4.039220e-32
# primary_cleaner.state.floatbank8_d_level           -7.997943e+02
# primary_cleaner.output.concentrate_pb               0.000000e+00
# primary_cleaner.output.concentrate_sol              0.000000e+00
# primary_cleaner.output.tail_ag                      0.000000e+00
# primary_cleaner.output.tail_pb                      0.000000e+00
# primary_cleaner.output.tail_sol                     0.000000e+00
# secondary_cleaner.state.floatbank2_a_air            7.750256e-02
# secondary_cleaner.state.floatbank2_a_level         -7.996064e+02
# secondary_cleaner.state.floatbank2_b_air            0.000000e+00
# secondary_cleaner.state.floatbank2_b_level         -7.998739e+02
# secondary_cleaner.state.floatbank3_a_air            0.000000e+00
# secondary_cleaner.state.floatbank3_a_level         -7.997558e+02
# secondary_cleaner.state.floatbank3_b_air            0.000000e+00
# secondary_cleaner.state.floatbank3_b_level         -8.093330e+02
# secondary_cleaner.state.floatbank4_a_air            0.000000e+00
# secondary_cleaner.state.floatbank4_a_level         -7.997985e+02
# secondary_cleaner.state.floatbank4_b_air            0.000000e+00
# secondary_cleaner.state.floatbank4_b_level         -8.008369e+02
# secondary_cleaner.state.floatbank5_a_air           -3.720540e-01
# secondary_cleaner.state.floatbank5_a_level         -7.973240e+02
# secondary_cleaner.state.floatbank5_b_air            5.280828e-01
# secondary_cleaner.state.floatbank5_b_level         -8.002203e+02
# secondary_cleaner.state.floatbank6_a_air           -7.942623e-02
# secondary_cleaner.state.floatbank6_a_level         -8.097415e+02
# secondary_cleaner.output.tail_ag                    0.000000e+00
# secondary_cleaner.output.tail_pb                    0.000000e+00
# secondary_cleaner.output.tail_sol                   0.000000e+00
# final.output.concentrate_ag                         0.000000e+00
# final.output.concentrate_pb                         0.000000e+00
# final.output.concentrate_sol                        0.000000e+00
# final.output.tail_ag                                0.000000e+00
# final.output.tail_pb                                0.000000e+00
# final.output.tail_sol                               0.000000e+00
#
#                                                              25%  \
# rougher.input.feed_pb                                   2.887280
# rougher.input.feed_sol                                 34.207799
# rougher.input.feed_rate                               416.525453
# rougher.input.feed_size                                47.435103
# rougher.input.floatbank10_sulfate                      10.000362
# rougher.input.floatbank10_xanthate                      5.398678
# rougher.state.floatbank10_a_air                       999.661867
# rougher.state.floatbank10_a_level                    -499.835165
# rougher.state.floatbank10_b_air                      1199.626115
# rougher.state.floatbank10_b_level                    -500.201130
# rougher.state.floatbank10_c_air                      1151.076301
# rougher.state.floatbank10_c_level                    -500.217218
# rougher.state.floatbank10_e_air                       998.675263
# rougher.input.floatbank11_sulfate                       9.998460
# rougher.input.floatbank11_xanthate                      5.402368
# rougher.calculation.sulfate_to_au_concentrate       40700.946040
# rougher.calculation.floatbank10_sulfate_to_au_feed   2611.425833
# rougher.calculation.floatbank11_sulfate_to_au_feed   2551.437587
# rougher.output.concentrate_sol                         27.224120
# rougher.output.tail_ag                                  4.889892
# primary_cleaner.input.sulfate                         114.107029
# primary_cleaner.input.depressant                        6.076909
# primary_cleaner.input.xanthate                          0.697224
# primary_cleaner.state.floatbank8_a_air               1505.063192
# primary_cleaner.state.floatbank8_a_level             -500.308544
# primary_cleaner.state.floatbank8_b_air               1503.629878
# primary_cleaner.state.floatbank8_b_level             -500.437171
# primary_cleaner.state.floatbank8_c_air               1500.926924
# primary_cleaner.state.floatbank8_c_level             -500.703932
# primary_cleaner.state.floatbank8_d_air               1494.219469
# primary_cleaner.state.floatbank8_d_level             -500.458365
# primary_cleaner.output.concentrate_pb                   8.702328
# primary_cleaner.output.concentrate_sol                  7.893893
# primary_cleaner.output.tail_ag                         14.017742
# primary_cleaner.output.tail_pb                          2.504365
# primary_cleaner.output.tail_sol                         6.747483
# secondary_cleaner.state.floatbank2_a_air               25.048462
# secondary_cleaner.state.floatbank2_a_level           -500.233700
# secondary_cleaner.state.floatbank2_b_air               20.919853
# secondary_cleaner.state.floatbank2_b_level           -500.253794
# secondary_cleaner.state.floatbank3_a_air               24.949227
# secondary_cleaner.state.floatbank3_a_level           -500.213546
# secondary_cleaner.state.floatbank3_b_air               18.995924
# secondary_cleaner.state.floatbank3_b_level           -500.123034
# secondary_cleaner.state.floatbank4_a_air               14.975734
# secondary_cleaner.state.floatbank4_a_level           -500.704892
# secondary_cleaner.state.floatbank4_b_air               11.940294
# secondary_cleaner.state.floatbank4_b_level           -500.187742
# secondary_cleaner.state.floatbank5_a_air               10.988606
# secondary_cleaner.state.floatbank5_a_level           -500.458467
# secondary_cleaner.state.floatbank5_b_air                8.971105
# secondary_cleaner.state.floatbank5_b_level           -500.129462
# secondary_cleaner.state.floatbank6_a_air               14.983037
# secondary_cleaner.state.floatbank6_a_level           -500.728067
# secondary_cleaner.output.tail_ag                       12.640239
# secondary_cleaner.output.tail_pb                        3.864733
# secondary_cleaner.output.tail_sol                       3.845475
# final.output.concentrate_ag                             4.251240
# final.output.concentrate_pb                             9.137262
# final.output.concentrate_sol                            7.722820
# final.output.tail_ag                                    8.062878
# final.output.tail_pb                                    2.040119
# final.output.tail_sol                                   8.938947
#
#                                                              50%  \
# rougher.input.feed_pb                                   3.534895
# rougher.input.feed_sol                                 37.202650
# rougher.input.feed_rate                               499.416120
# rougher.input.feed_size                                54.610197
# rougher.input.floatbank10_sulfate                      12.001174
# rougher.input.floatbank10_xanthate                      6.008273
# rougher.state.floatbank10_a_air                      1001.072890
# rougher.state.floatbank10_a_level                    -300.263994
# rougher.state.floatbank10_b_air                      1301.579988
# rougher.state.floatbank10_b_level                    -499.784045
# rougher.state.floatbank10_c_air                      1300.211537
# rougher.state.floatbank10_c_level                    -499.713364
# rougher.state.floatbank10_e_air                      1050.029461
# rougher.input.floatbank11_sulfate                      12.000204
# rougher.input.floatbank11_xanthate                      6.098580
# rougher.calculation.sulfate_to_au_concentrate       44696.480712
# rougher.calculation.floatbank10_sulfate_to_au_feed   3018.353876
# rougher.calculation.floatbank11_sulfate_to_au_feed   2997.218088
# rougher.output.concentrate_sol                         29.835345
# rougher.output.tail_ag                                  5.765802
# primary_cleaner.input.sulfate                         143.232103
# primary_cleaner.input.depressant                        8.038311
# primary_cleaner.input.xanthate                          0.940863
# primary_cleaner.state.floatbank8_a_air               1600.596566
# primary_cleaner.state.floatbank8_a_level             -499.926134
# primary_cleaner.state.floatbank8_b_air               1600.520975
# primary_cleaner.state.floatbank8_b_level             -499.956767
# primary_cleaner.state.floatbank8_c_air               1600.253890
# primary_cleaner.state.floatbank8_c_level             -499.909524
# primary_cleaner.state.floatbank8_d_air               1599.447470
# primary_cleaner.state.floatbank8_d_level             -499.905974
# primary_cleaner.output.concentrate_pb                  10.152433
# primary_cleaner.output.concentrate_sol                 10.314632
# primary_cleaner.output.tail_ag                         15.842836
# primary_cleaner.output.tail_pb                          3.271153
# primary_cleaner.output.tail_sol                         8.183673
# secondary_cleaner.state.floatbank2_a_air               29.099943
# secondary_cleaner.state.floatbank2_a_level           -499.973250
# secondary_cleaner.state.floatbank2_b_air               25.043289
# secondary_cleaner.state.floatbank2_b_level           -500.015439
# secondary_cleaner.state.floatbank3_a_air               27.982129
# secondary_cleaner.state.floatbank3_a_level           -499.930680
# secondary_cleaner.state.floatbank3_b_air               22.011231
# secondary_cleaner.state.floatbank3_b_level           -499.981902
# secondary_cleaner.state.floatbank4_a_air               18.017481
# secondary_cleaner.state.floatbank4_a_level           -499.837793
# secondary_cleaner.state.floatbank4_b_air               14.971014
# secondary_cleaner.state.floatbank4_b_level           -499.459786
# secondary_cleaner.state.floatbank5_a_air               15.000036
# secondary_cleaner.state.floatbank5_a_level           -499.802605
# secondary_cleaner.state.floatbank5_b_air               11.019433
# secondary_cleaner.state.floatbank5_b_level           -499.935317
# secondary_cleaner.state.floatbank6_a_air               19.960541
# secondary_cleaner.state.floatbank6_a_level           -500.048400
# secondary_cleaner.output.tail_ag                       15.641902
# secondary_cleaner.output.tail_pb                        5.344073
# secondary_cleaner.output.tail_sol                       7.685827
# final.output.concentrate_ag                             5.066094
# final.output.concentrate_pb                            10.102433
# final.output.concentrate_sol                            9.218961
# final.output.tail_ag                                    9.743623
# final.output.tail_pb                                    2.748730
# final.output.tail_sol                                  10.622456
#
#                                                              75%           max
# rougher.input.feed_pb                                   4.244161  7.142594e+00
# rougher.input.feed_sol                                 40.039133  5.347774e+01
# rougher.input.feed_rate                               550.172183  7.175088e+02
# rougher.input.feed_size                                65.023044  4.849675e+02
# rougher.input.floatbank10_sulfate                      14.716595  3.611827e+01
# rougher.input.floatbank10_xanthate                      6.798051  9.703448e+00
# rougher.state.floatbank10_a_air                      1205.620588  1.521980e+03
# rougher.state.floatbank10_a_level                    -299.981998 -2.737761e+02
# rougher.state.floatbank10_b_air                      1448.630789  1.809194e+03
# rougher.state.floatbank10_b_level                    -400.615589 -2.963831e+02
# rougher.state.floatbank10_c_air                      1449.464001  2.499129e+03
# rougher.state.floatbank10_c_level                    -400.985743 -2.921555e+02
# rougher.state.floatbank10_e_air                      1199.425140  1.922637e+03
# rougher.input.floatbank11_sulfate                      14.636766  3.798065e+01
# rougher.input.floatbank11_xanthate                      6.801233  9.698407e+00
# rougher.calculation.sulfate_to_au_concentrate       48168.210371  3.428099e+06
# rougher.calculation.floatbank10_sulfate_to_au_feed   3676.769750  6.296390e+05
# rougher.calculation.floatbank11_sulfate_to_au_feed   3601.998911  7.186850e+05
# rougher.output.concentrate_sol                         32.189933  3.835119e+01
# rougher.output.tail_ag                                  6.389234  1.271918e+01
# primary_cleaner.input.sulfate                         175.075656  2.659831e+02
# primary_cleaner.input.depressant                       11.013521  4.000000e+01
# primary_cleaner.input.xanthate                          1.210990  4.102454e+00
# primary_cleaner.state.floatbank8_a_air               1697.657718  2.103104e+03
# primary_cleaner.state.floatbank8_a_level             -499.433950 -5.719540e+01
# primary_cleaner.state.floatbank8_b_air               1699.217656  2.114907e+03
# primary_cleaner.state.floatbank8_b_level             -499.373336 -1.425272e+02
# primary_cleaner.state.floatbank8_c_air               1699.482929  2.013156e+03
# primary_cleaner.state.floatbank8_c_level             -498.857643 -1.509370e+02
# primary_cleaner.state.floatbank8_d_air               1698.524904  2.398904e+03
# primary_cleaner.state.floatbank8_d_level             -499.064695 -3.060183e+01
# primary_cleaner.output.concentrate_pb                  11.424971  1.708128e+01
# primary_cleaner.output.concentrate_sol                 13.446702  2.245811e+01
# primary_cleaner.output.tail_ag                         18.013975  2.945957e+01
# primary_cleaner.output.tail_pb                          4.181748  9.634565e+00
# primary_cleaner.output.tail_sol                         9.548586  2.227636e+01
# secondary_cleaner.state.floatbank2_a_air               33.012536  5.265140e+01
# secondary_cleaner.state.floatbank2_a_level           -499.671261 -1.278756e+02
# secondary_cleaner.state.floatbank2_b_air               28.008197  3.515212e+01
# secondary_cleaner.state.floatbank2_b_level           -499.785698 -2.119993e+02
# secondary_cleaner.state.floatbank3_a_air               33.002798  4.426046e+01
# secondary_cleaner.state.floatbank3_a_level           -499.325739 -1.916788e+02
# secondary_cleaner.state.floatbank3_b_air               25.998206  3.507284e+01
# secondary_cleaner.state.floatbank3_b_level           -499.812834 -1.597423e+02
# secondary_cleaner.state.floatbank4_a_air               23.012470  3.011574e+01
# secondary_cleaner.state.floatbank4_a_level           -498.249730 -2.452392e+02
# secondary_cleaner.state.floatbank4_b_air               19.034162  3.126971e+01
# secondary_cleaner.state.floatbank4_b_level           -400.118106 -6.506986e+00
# secondary_cleaner.state.floatbank5_a_air               18.026190  4.370993e+01
# secondary_cleaner.state.floatbank5_a_level           -498.384187 -2.444836e+02
# secondary_cleaner.state.floatbank5_b_air               14.019088  2.792600e+01
# secondary_cleaner.state.floatbank5_b_level           -499.436708 -1.377400e+02
# secondary_cleaner.state.floatbank6_a_air               24.003170  3.218891e+01
# secondary_cleaner.state.floatbank6_a_level           -499.495378 -1.044275e+02
# secondary_cleaner.output.tail_ag                       17.358217  2.326474e+01
# secondary_cleaner.output.tail_pb                        7.788467  1.704250e+01
# secondary_cleaner.output.tail_sol                      10.411296  2.600077e+01
# final.output.concentrate_ag                             5.895527  1.600195e+01
# final.output.concentrate_pb                            11.035769  1.703190e+01
# final.output.concentrate_sol                           10.947813  1.961572e+01
# final.output.tail_ag                                   11.134294  1.955215e+01
# final.output.tail_pb                                    3.333216  5.804178e+00
# final.output.tail_sol                                  12.104271  2.231773e+01

# %%
for i in [df, df_train, df_test]:
    i.fillna(method='ffill', inplace=True)

# %% [markdown]
# проверим, не осталось ли пропусков

# %%
display(df.isna().sum()[df.isna().sum() > 0], df_train.isna().sum()[df_train.isna().sum() > 0],df_test.isna().sum()[df_test.isna().sum() > 0])
# Out:
# Series([], dtype: int64)
# Series([], dtype: int64)
# Series([], dtype: int64)

# %% [markdown]
# **Вывод**
# - Эффективность обогащения rougher.output.recovery в обучающей выборке рассчитана верно.
# - Обучающая и тестовая выборка предобработаны. Количество столбцов составило 55.
# - Заполнены все пропуски в во всех таблицах.

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Изменение концентрации элементов на каждом этапе

# %% [markdown]
# Посмотрим, как меняется концентрация металлов (Au, Ag, Pb) на различных этапах: в сырье, в черновом концентрате, в концентрате после первой очистки и в финальном концентрате. Какие особенности имеют распределения?

# %%
metal=['au', 'ag', 'pb'] #металл

# %%
# создаём цикл для вывода необходимых графиков
for met in metal:
    plt.figure(figsize=(10,7))
    legend=[]
    for col in df.columns:
        if ('concentrate_'+met) in col or  ('rougher.input.feed_'+ met) in col:
            df[col].hist(alpha=0.7, edgecolor='k')
            legend.append(col)
    plt.title(f'Концентрация {met} на различных этапах', fontsize='xx-large')
    plt.legend(legend)
    plt.xlabel("концентрация металла")
    plt.ylabel("кол-во измерений")
    plt.show();

# %% [markdown]
# **Просмотрев графики можно сделать вывод:**
#
# - Концентрация золота постепенно увеличивается с каждым этапом очистки
# - Концентрация серебра уменьшается
# - Концентрация свинца практически остается на одинаковом уровне.

# %% [markdown]
# На всех этапах обработки имеются нулевые значения концентрации. Для всех признаков - это аномальные значения (выбросы).

# %% [markdown]
# Так как нулевые значения в концентрациях могут повлиять на модель машинного обучения, удалим такие строки.

# %%
index_clean=[]
for met in metal:    
    for col in df.columns:
        if ('concentrate_'+met) in col:
            for i in range(len(df)-1):
                if df[col][i] == 0:
                    index_clean.append(df['date'][i])

# %%
df=df.drop(df[df['date'].isin(index_clean)].index, axis=0)
df_train=df_train.drop(df_train[df_train['date'].isin(index_clean)].index, axis=0)
df_test=df_test.drop(df_test[df_test['date'].isin(index_clean)].index, axis=0)

# %%
print('размер данных:',df.shape)
print('размер обучающей выборки:',df_train.shape)
print('размер тестовой выборки:',df_test.shape)
# Out:
# размер данных: (18842, 87)
# размер обучающей выборки: (13982, 55)
# размер тестовой выборки: (4860, 55)

# %% [markdown]
# ### Распределения размеров гранул на обучающей и тестовой выборках

# %%
name=[]
for col in df_train.columns:
    if ('feed_size') in col:       
        name.append(col)

# %%
for i in name:
    plt.figure(figsize = (15,7))
    ax = sns.kdeplot(df_train[i],                     
                      alpha=0.7)
    ax.lines[0].set_color('black')
    
    ax = sns.kdeplot(df_test[i],
                      color='green',                   
                      alpha=0.7)
    
    ax.lines[1].set_color('crimson')
    plt.title(f'Распределение значений размера гранул сырья на тестовой и обучающей выборке, этап-{i}')
    plt.xlabel("размер гранул")
    plt.ylabel("плотность распределения")
    plt.legend(['Тестовая выборка','Обучающая выборка'])
plt.show();

# %% [markdown]
# Распределения гранул сырья на обеих выборках нормальные. На этапе rougher распределение смещено влево.
# Такое распределение не повлияет негативно на обучение моделей, оставим значения без изменений.

# %% [markdown]
# ### Исследуем суммарные концентрации

# %% [markdown]
# Исследуем суммарную концентрацию всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.
#
# посчитаем суммарную концентрацию на этапах:
#
# - ``rougher.input.feed`` - входящее сырье
# - ``rougher.output.concentrate_`` - черновой концентрат после флотации
# - ``primary_cleaner.output.concentrate_`` - черновой концентрат после первичной обработки
# - ``final.output.concentrate`` - финальная концентрация

# %%
concentrate=['rougher.input.feed','rougher.output.concentrate','primary_cleaner.output.concentrate', 'final.output.concentrate']
for con in concentrate:
    df[con+'_summ']=0
    for col in df.columns:
        if (con) in col and ('_size' not in col and '_rate' not in col):          
            df[con+'_summ']=df[con+'_summ']+df[col]

# %%
df.iloc[0:5,-5:]
# Out:
#    final.output.tail_sol  rougher.input.feed_summ  \
# 0              16.904297               103.360067
# 1              16.634514               101.318228
# 2              16.208849               101.219857
# 3              16.532835               102.123091
# 4              16.525686                95.718326
#
#    rougher.output.concentrate_summ  primary_cleaner.output.concentrate_summ  \
# 0                       132.849899                               145.281847
# 1                       134.025421                               145.086969
# 2                       132.207585                               144.190085
# 3                       131.505501                               119.915446
# 4                       131.816764                               142.642020
#
#    final.output.concentrate_summ
# 0                     127.288792
# 1                     127.915447
# 2                     128.622360
# 3                     127.146898
# 4                     128.009334

# %%
plt.figure(figsize = (15,10))
ax = sns.histplot(df.iloc[:,-4:], 
                      bins=50,                        
                      alpha=0.8)
plt.title('Cуммарная концентрация всех веществ на разных стадиях')
plt.xlabel("концентрация всех веществ")
plt.ylabel("кол-во измерений")
plt.show();

# %%
df.iloc[:,-4:].describe().T
# Out:
#                                            count        mean        std   min  \
# rougher.input.feed_summ                  18842.0  114.646960  14.342356  0.08
# rougher.output.concentrate_summ          18842.0  139.170805  15.519622  0.08
# primary_cleaner.output.concentrate_summ  18842.0  122.153302  17.768185  0.08
# final.output.concentrate_summ            18842.0  138.032961  11.042076  0.08
#
#                                                 25%         50%         75%  \
# rougher.input.feed_summ                  107.055465  115.192632  123.931996
# rougher.output.concentrate_summ          132.656576  140.628170  148.890477
# primary_cleaner.output.concentrate_summ  118.012979  124.992743  131.275530
# final.output.concentrate_summ            135.892519  139.201733  142.749181
#
#                                                 max
# rougher.input.feed_summ                  153.957895
# rougher.output.concentrate_summ          176.280239
# primary_cleaner.output.concentrate_summ  161.498686
# final.output.concentrate_summ            160.421288

# %% [markdown]
# Как видно из гистограмм распределения нормальные

# %% [markdown]
# **Вывод**
#
# - Концентрация золота постепенно увеличивается с каждым этапом очистки
# - Концентрация серебра уменьшается
# - Концентрация свинца практически остается на одинаковом уровне.
# - Концентрация всех веществ во входящем сырье ниже, чем концентрация после финального этапа на выходе.
# - Максимальная суммарная концентрация на этапе rougher.output.concentrate 176.28.
# - На всех этапах есть показатели значения концентрации близкие к нулю. Взможно это техничесикй сбой, либо действительно "пустая" порода.
# - Средние значения концентрации металов на всех этапах колеблятся в пределах 114-139
# - Распределения гранул сырья на обеих выборках нормальные.  Для моделей машинного обучения такое распределение не повлияет негативно.
# - Строки с пустым значением концетрации удалены.

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Напишим функции для вычисления итоговой sMAPE.

# %%
#sMAPE(target, predict) - расчет метрики качества для предсказания модели
def sMAPE(target, predict):
    
    smape = (np.sum((abs(target - predict)) / ((abs(target) + abs(predict)) / 2))) * 100 / len(target)
    
    return smape

# %%
#final_sMAPE(rougher, final) - Итоговая метрика складывается из двух величин
def final_sMAPE(smape_rougher, smape_final): 
    final_smape = 0.25 * smape_rougher + 0.75 * smape_final
    return final_smape

# %% [markdown]
# Cделаем scorer из нашей функции

# %%
sMAPE_scorer = make_scorer(sMAPE, greater_is_better=False)

# %% [markdown]
# Целевые признаки у нас:
# - ``rougher.output.recovery`` эффективность обогащения чернового концентрата
# - ``final.output.recovery``эффективность обогащения финального концентрата

# %%
print('Размер обучающей выборки до разделения', df_train.shape)
print('Размер тестовой выборки до разделения', df_test.shape)
# Out:
# Размер обучающей выборки до разделения (13982, 55)
# Размер тестовой выборки до разделения (4860, 55)

# %%
def separation(data): # создадим функция для разделения данных на целевые признаки и на признаки
    features = data.drop(['rougher.output.recovery','final.output.recovery','date'], axis=1)
    target_rougher = data['rougher.output.recovery']
    target_final = data['final.output.recovery']
    print('Размер  выборки с признаками', features.shape)
    print('Размер  выборки с целевым признакам чернового концентрата', target_rougher.shape)
    print('Размер  выборки с целевым признакам финального концентрата', target_final.shape)
    return features,target_rougher, target_final

# %%
print('Обучающая выборка после разделения')
features_train,target_rougher_train, target_final_train=separation(df_train)
# Out:
# Обучающая выборка после разделения
# Размер  выборки с признаками (13982, 52)
# Размер  выборки с целевым признакам чернового концентрата (13982,)
# Размер  выборки с целевым признакам финального концентрата (13982,)

# %%
print('Тестовая выборка после разделения')
features_test,target_rougher_test, target_final_test=separation(df_test)
# Out:
# Тестовая выборка после разделения
# Размер  выборки с признаками (4860, 52)
# Размер  выборки с целевым признакам чернового концентрата (4860,)
# Размер  выборки с целевым признакам финального концентрата (4860,)

# %%
features_train.describe().astype('int').T
# Out:
#                                             count  mean  std  min   25%   50%  \
# rougher.input.feed_au                       13982     8    1    0     6     8
# rougher.input.feed_ag                       13982     8    1    0     7     8
# rougher.input.feed_pb                       13982     3    1    0     2     3
# rougher.input.feed_sol                      13982    36    5    0    34    37
# rougher.input.feed_rate                     13982   476  106    0   416   498
# rougher.input.feed_size                     13982    59   23    0    47    54
# rougher.input.floatbank10_sulfate           13982    12    3    0    10    12
# rougher.input.floatbank10_xanthate          13982     6    1    0     5     6
# rougher.state.floatbank10_a_air             13982  1103  161    0   999  1000
# rougher.state.floatbank10_a_level           13982  -380   94 -657  -499  -300
# rougher.state.floatbank10_b_air             13982  1326  180    0  1199  1303
# rougher.state.floatbank10_b_level           13982  -464   56 -650  -500  -499
# rougher.state.floatbank10_c_air             13982  1306  208    0  1151  1301
# rougher.state.floatbank10_c_level           13982  -465   55 -647  -500  -499
# rougher.state.floatbank10_d_air             13982  1218  208    0  1078  1203
# rougher.state.floatbank10_d_level           13982  -466   55 -648  -500  -499
# rougher.state.floatbank10_e_air             13982  1080  178   -1   997  1049
# rougher.state.floatbank10_e_level           13982  -463   59 -649  -500  -499
# rougher.state.floatbank10_f_air             13982  1028  170   -2   900   999
# rougher.state.floatbank10_f_level           13982  -464   59 -649  -500  -499
# rougher.input.floatbank11_sulfate           13982    12    3    0     9    12
# rougher.input.floatbank11_xanthate          13982     5    1    0     5     6
# primary_cleaner.input.sulfate               13982   145   44    0   115   145
# primary_cleaner.input.depressant            13982     8    3    0     6     8
# primary_cleaner.input.feed_size             13982     7    0    1     6     7
# primary_cleaner.input.xanthate              13982     1    0    0     0     0
# primary_cleaner.state.floatbank8_a_air      13982  1590  128    0  1507  1600
# primary_cleaner.state.floatbank8_a_level    13982  -491   30 -783  -500  -499
# primary_cleaner.state.floatbank8_b_air      13982  1593  129    0  1509  1600
# primary_cleaner.state.floatbank8_b_level    13982  -492   32 -799  -500  -499
# primary_cleaner.state.floatbank8_c_air      13982  1587  135    0  1500  1600
# primary_cleaner.state.floatbank8_c_level    13982  -492   31 -799  -500  -499
# primary_cleaner.state.floatbank8_d_air      13982  1546  243    0  1497  1599
# primary_cleaner.state.floatbank8_d_level    13982  -488   43 -799  -500  -499
# secondary_cleaner.state.floatbank2_a_air    13982    28    5    0    25    29
# secondary_cleaner.state.floatbank2_a_level  13982  -502   56 -799  -500  -499
# secondary_cleaner.state.floatbank2_b_air    13982    23    5    0    20    24
# secondary_cleaner.state.floatbank2_b_level  13982  -503   59 -799  -500  -500
# secondary_cleaner.state.floatbank3_a_air    13982    28    6    0    24    27
# secondary_cleaner.state.floatbank3_a_level  13982  -484   55 -799  -500  -499
# secondary_cleaner.state.floatbank3_b_air    13982    22    5    0    18    22
# secondary_cleaner.state.floatbank3_b_level  13982  -492   43 -809  -500  -499
# secondary_cleaner.state.floatbank4_a_air    13982    18    5    0    14    18
# secondary_cleaner.state.floatbank4_a_level  13982  -484   48 -799  -500  -499
# secondary_cleaner.state.floatbank4_b_air    13982    14    4    0    11    14
# secondary_cleaner.state.floatbank4_b_level  13982  -460   66 -800  -500  -499
# secondary_cleaner.state.floatbank5_a_air    13982    15    5    0    10    14
# secondary_cleaner.state.floatbank5_a_level  13982  -487   35 -797  -500  -499
# secondary_cleaner.state.floatbank5_b_air    13982    12    5    0     8    11
# secondary_cleaner.state.floatbank5_b_level  13982  -486   38 -800  -500  -499
# secondary_cleaner.state.floatbank6_a_air    13982    19    5    0    14    19
# secondary_cleaner.state.floatbank6_a_level  13982  -505   36 -809  -500  -500
#
#                                              75%   max
# rougher.input.feed_au                          9    13
# rougher.input.feed_ag                         10    14
# rougher.input.feed_pb                          4     7
# rougher.input.feed_sol                        39    53
# rougher.input.feed_rate                      549   717
# rougher.input.feed_size                       64   484
# rougher.input.floatbank10_sulfate             14    36
# rougher.input.floatbank10_xanthate             6     9
# rougher.state.floatbank10_a_air             1208  1512
# rougher.state.floatbank10_a_level           -299  -273
# rougher.state.floatbank10_b_air             1450  1809
# rougher.state.floatbank10_b_level           -400  -296
# rougher.state.floatbank10_c_air             1450  2499
# rougher.state.floatbank10_c_level           -400  -292
# rougher.state.floatbank10_d_air             1391  1817
# rougher.state.floatbank10_d_level           -401   -76
# rougher.state.floatbank10_e_air             1199  1922
# rougher.state.floatbank10_e_level           -400  -139
# rougher.state.floatbank10_f_air             1099  1706
# rougher.state.floatbank10_f_level           -401  -191
# rougher.input.floatbank11_sulfate             14    37
# rougher.input.floatbank11_xanthate             6     9
# primary_cleaner.input.sulfate                176   265
# primary_cleaner.input.depressant              11    40
# primary_cleaner.input.feed_size                7    15
# primary_cleaner.input.xanthate                 1     4
# primary_cleaner.state.floatbank8_a_air      1697  2074
# primary_cleaner.state.floatbank8_a_level    -499   -57
# primary_cleaner.state.floatbank8_b_air      1699  1846
# primary_cleaner.state.floatbank8_b_level    -499  -142
# primary_cleaner.state.floatbank8_c_air      1699  2013
# primary_cleaner.state.floatbank8_c_level    -498  -150
# primary_cleaner.state.floatbank8_d_air      1698  2398
# primary_cleaner.state.floatbank8_d_level    -499   -30
# secondary_cleaner.state.floatbank2_a_air      32    52
# secondary_cleaner.state.floatbank2_a_level  -499  -127
# secondary_cleaner.state.floatbank2_b_air      28    35
# secondary_cleaner.state.floatbank2_b_level  -499  -211
# secondary_cleaner.state.floatbank3_a_air      32    44
# secondary_cleaner.state.floatbank3_a_level  -499  -191
# secondary_cleaner.state.floatbank3_b_air      25    35
# secondary_cleaner.state.floatbank3_b_level  -499  -159
# secondary_cleaner.state.floatbank4_a_air      22    30
# secondary_cleaner.state.floatbank4_a_level  -498  -245
# secondary_cleaner.state.floatbank4_b_air      17    24
# secondary_cleaner.state.floatbank4_b_level  -400    -7
# secondary_cleaner.state.floatbank5_a_air      18    43
# secondary_cleaner.state.floatbank5_a_level  -498  -244
# secondary_cleaner.state.floatbank5_b_air      14    27
# secondary_cleaner.state.floatbank5_b_level  -499  -137
# secondary_cleaner.state.floatbank6_a_air      23    32
# secondary_cleaner.state.floatbank6_a_level  -499  -123

# %%
plt.figure(figsize = (20,15))
ax = sns.kdeplot(data=features_train,                    
                      alpha=0.8)
plt.title('Распределение признаков')
plt.xlabel("Значения")
plt.ylabel("Кол-во измерений")
plt.show();

# %% [markdown]
# Исходные признаки имеют разный масштаб.Стандартизируем признаки

# %%
scaler = StandardScaler()
scaler.fit(features_train) 

features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %%
plt.figure(figsize = (20,15))
ax = sns.kdeplot(data=features_train,                    
                      alpha=0.8)
plt.title('Распределение признаков после стандартизации')
plt.xlabel("Значения")
plt.ylabel("Кол-во измерений")
plt.show();

# %% [markdown]
# ### Обучение моделей

# %% [markdown]
# Для обучения возьмем:
#
# - линейную регрессию
# - дерево регрессии
# - случайный лес регрессии

# %%
def model_metric(model, features, target):
    score = (-1)*cross_val_score(model, features, target,scoring=sMAPE_scorer, cv=3, n_jobs=-1)  
    
    return score.mean()

# %% [markdown]
# #### Линейная регрессия

# %%
model = LinearRegression()
score_rougher_train=model_metric(model, features_train, target_rougher_train)
print('Средняя оценка качества модели обогащения чернового концентрата:{:.4f}'.format(score_rougher_train))
# Out:
# Средняя оценка качества модели обогащения чернового концентрата:8.2184

# %%
model = LinearRegression()
score_final_train=model_metric(model,features_train, target_final_train)
print('Средняя оценка качества модели обогащения финального концентрата :{:.4f}'.format(score_final_train))
# Out:
# Средняя оценка качества модели обогащения финального концентрата :10.9135

# %%
print('Симметричное среднее абсолютное процентное отклонение :{:.4f}'
      .format(final_sMAPE(score_rougher_train, score_final_train)))
# Out:
# Симметричное среднее абсолютное процентное отклонение :10.2397

# %% [markdown]
# ####  Дерево решений

# %%
best_tree = 0 
score_rougher = 1000

for depth in range(2, 20):
    model = DecisionTreeRegressor(random_state=12345, max_depth=depth)
    score_rougher_train=model_metric(model, features_train, target_rougher_train)    
    print(score_rougher, score_rougher_train)
    if score_rougher > score_rougher_train:
        score_rougher = score_rougher_train
        best_tree = depth

print('depth:',best_tree)
print('Средняя оценка качества модели обогащения чернового концентрата:{:.4f}'.format(score_rougher))
# Out:
# 1000 7.21792094013994
# 7.21792094013994 6.991157248748291
# 6.991157248748291 6.880699855466137
# 6.880699855466137 7.288062088926438
# 6.880699855466137 7.379199660502896
# 6.880699855466137 7.111297552235793
# 6.880699855466137 7.536793111416638
# 6.880699855466137 7.873704766182674
# 6.880699855466137 7.6999489654519095
# 6.880699855466137 7.874182313817972
# 6.880699855466137 7.9698667697024845
# 6.880699855466137 8.128553302328195
# 6.880699855466137 8.462528873439856
# 6.880699855466137 8.200091962906424
# 6.880699855466137 8.510552090263234
# 6.880699855466137 8.567323044441592
# 6.880699855466137 8.671196068251204
# 6.880699855466137 8.647839006284661
# depth: 4
# Средняя оценка качества модели обогащения чернового концентрата:6.8807

# %%
best_tree = 0 
score_final = 1000

for depth in range(2, 20):
    model = DecisionTreeRegressor(random_state=12345, max_depth=depth)
    score_final_train=model_metric(model, features_train, target_final_train)
    if score_final > score_final_train:
        score_final = score_final_train
        best_tree = depth

print('depth:',best_tree)
print('Средняя оценка качества модели обогащения финального концентрата:{:.4f}'.format(score_final))
# Out:
# depth: 2
# Средняя оценка качества модели обогащения финального концентрата:9.6556

# %%
print('Симметричное среднее абсолютное процентное отклонение :{:.4f}'
      .format(final_sMAPE(score_rougher, score_final)))
# Out:
# Симметричное среднее абсолютное процентное отклонение :8.9618

# %% [markdown]
# #### Cлучайный лес

# %%
depth_random = 0
n_est_random = 0
score_rougher = 1000

for depth in range(1,21,2):         
        for est in range(50, 100, 10):
            model = RandomForestRegressor(random_state=12345,
                                           max_depth=depth,                                           
                                           n_estimators=est)
            score_rougher_train=model_metric(model, features_train, target_rougher_train)
            if score_rougher > score_rougher_train:
                score_rougher = score_rougher_train
                best_random = depth
                n_est_random =est 
print('depth:',best_random)
print('n_estimators:',n_est_random)
print('Средняя оценка качества модели обогащения чернового концентрата:{:.4f}'.format(score_rougher))
# Out:
# depth: 5
# n_estimators: 70
# Средняя оценка качества модели обогащения чернового концентрата:6.5988

# %%
depth_random = 0
n_est_random = 0
score_final = 1000

for depth in range(1,21,2):         
        for est in range(50, 100, 10):
            model = RandomForestRegressor(random_state=12345,
                                           max_depth=depth,                                           
                                           n_estimators=est)
            score_final_train=model_metric(model, features_train, target_final_train)
            if score_final > score_rougher_train:
                score_final = score_rougher_train
                best_random = depth
                n_est_random =est 
print('depth:',best_random)
print('n_estimators:',n_est_random)
print('Средняя оценка качества модели обогащения финального концентрата:{:.4f}'.format(score_final))
# Out:
# depth: 1
# n_estimators: 50
# Средняя оценка качества модели обогащения финального концентрата:6.9461

# %%
print('Симметричное среднее абсолютное процентное отклонение :{:.4f}'
      .format(final_sMAPE(score_rougher, score_final)))
# Out:
# Симметричное среднее абсолютное процентное отклонение :6.8593

# %% [markdown]
# **Вывод**
#
# Лучшая модель **Cлучайный лес** показала:
# - sMAPE чернового концентрата: 6.5988
# - sMAPE финального концентрата: 6.9461
# - Итоговую sMAPE: 6.8593

# %% [markdown]
# ### Проверка лучшей модели на тестовой выборке

# %%
model =  RandomForestRegressor(random_state=12345,
                                           max_depth=1,                                           
                                           n_estimators=50)
model_rougher_train=model.fit(features_train, target_rougher_train)
predicted_rougher = model_rougher_train.predict(features_test)

model_final_train=model.fit(features_train, target_final_train)
predicted_final = model_rougher_train.predict(features_test)

print('Средняя оценка качества модели обогащения чернового концентрата:{:.4f}'
      .format(sMAPE(target_rougher_test, predicted_rougher)))    
print('Средняя оценка качества модели обогащения финального концентрата:{:.4f}'
      .format(sMAPE(target_final_test, predicted_final)))    
print('Симметричное среднее абсолютное процентное отклонение :{:.4f}'
      .format(final_sMAPE(sMAPE(target_rougher_test, predicted_rougher),
                          sMAPE(target_final_test, predicted_final))))
# Out:
# Средняя оценка качества модели обогащения чернового концентрата:5.8661
# Средняя оценка качества модели обогащения финального концентрата:8.7698
# Симметричное среднее абсолютное процентное отклонение :8.0438

# %% [markdown]
# ### Проверка модели на адекватность

# %%
dummy = DummyRegressor(strategy="mean")

dummy_rougher=dummy.fit(features_train, target_rougher_train)
predicted_rougher_dummy = dummy_rougher.predict(features_test)

dummy_final=dummy.fit(features_train, target_final_train)
predicted_final_dummy = dummy_final.predict(features_test)

print('Средняя оценка качества модели обогащения чернового концентрата:{:.4f}'
      .format(sMAPE(target_rougher_test, predicted_rougher_dummy)))    
print('Средняя оценка качества модели обогащения финального концентрата:{:.4f}'
      .format(sMAPE(target_final_test, predicted_final_dummy)))    
print('Симметричное среднее абсолютное процентное отклонение :{:.4f}'
      .format(final_sMAPE(sMAPE(target_rougher_test, predicted_rougher_dummy),
                          sMAPE(target_final_test, predicted_final_dummy))))
# Out:
# Средняя оценка качества модели обогащения чернового концентрата:6.1075
# Средняя оценка качества модели обогащения финального концентрата:9.2601
# Симметричное среднее абсолютное процентное отклонение :8.4719

# %% [markdown]
# **Вывод**
#
# Итоговый sMAPE модель Cлучайный лес на тестовой выборке - 8.0438 Проверка адекватности модели - sMAPE при DummyRegressor - 8,47.
#
# метрика sMAPE для DummyRegressor больше, чем для тестовой модели, это может означать, что тестовая модель лучше предсказывает значения целевой переменной, чем DummyRegressor.  Значит такую модель можно использовать.

# %% [markdown]
# **ВЫВОД**

# %% [markdown]
# - Обучающая и тестовая выборка были предобработаны. Количество столбцов составило 55.
# - Заполнены все пропуски  во всех таблицах, включая исходные данные.
# - Эффективность обогащения rougher.output.recovery в обучающей выборке была рассчитана верно.
# - Распределения гранул сырья на обеих выборках нормальные.
# - Строки с пустым значением концетрации были удалены.
# - Лучшая модель Cлучайного леса показала:
#  - sMAPE чернового концентрата: 6.5988
#  - sMAPE финального концентрата: 6.9461
#  - Итоговую sMAPE: 6.8593
# - Модель прошла проверку на тестовой выборке с показателями:
#  - sMAPE чернового концентрата: 5.8661
#  - sMAPE финального концентрата: 8.7698
#  - Итоговая sMAPE: 8.0438
# - Проверка модели на адекватность показала:
#  - sMAPE чернового концентрата: 6.1075
#  - sMAPE финального концентрата: 9.2601
#  - Итоговая sMAPE: 8.4719
